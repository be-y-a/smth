# %% [markdown]
# # Добрый вечер!

# %% [markdown]
# <h1>План Лекции<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Функции-в-Питоне" data-toc-modified-id="Функции-в-Питоне-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Функции в Питоне</a></span><ul class="toc-item"><li><span><a href="#Объявление-функции" data-toc-modified-id="Объявление-функции-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Объявление функции</a></span></li><li><span><a href="#Глобальные-и-локальные-переменные" data-toc-modified-id="Глобальные-и-локальные-переменные-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Глобальные и локальные переменные</a></span></li><li><span><a href="#Передача-аргументов" data-toc-modified-id="Передача-аргументов-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Передача аргументов</a></span></li><li><span><a href="#Типы-аргументов" data-toc-modified-id="Типы-аргументов-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Типы аргументов</a></span><ul class="toc-item"><li><span><a href="#Обязательные" data-toc-modified-id="Обязательные-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Обязательные</a></span></li><li><span><a href="#Аргументы-с-дефолтным-значением" data-toc-modified-id="Аргументы-с-дефолтным-значением-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Аргументы с дефолтным значением</a></span></li><li><span><a href="#Аргументы-с-переменной-длиной" data-toc-modified-id="Аргументы-с-переменной-длиной-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Аргументы с переменной длиной</a></span></li></ul></li><li><span><a href="#Рекурсивные-функции" data-toc-modified-id="Рекурсивные-функции-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Рекурсивные функции</a></span></li></ul></li><li><span><a href="#Работа-с-файлами/папками" data-toc-modified-id="Работа-с-файлами/папками-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Работа с файлами/папками</a></span><ul class="toc-item"><li><span><a href="#Чтение/запись-в-файл" data-toc-modified-id="Чтение/запись-в-файл-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Чтение/запись в файл</a></span><ul class="toc-item"><li><span><a href="#Контекстный-оператор-with" data-toc-modified-id="Контекстный-оператор-with-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Контекстный оператор with</a></span></li></ul></li><li><span><a href="#Работа-с-директориями" data-toc-modified-id="Работа-с-директориями-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Работа с директориями</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Функции в Питоне

# %% [markdown]
# Функции нужны для того, чтобы писать многократно используемый код, что обеспечивает читабельность и модулярность кода.
#
# Вы уже сталкивались с функциями, когда, например, использовали print.

# %% [markdown]
# ### Объявление функции

# %% [markdown]
# Напишем функцию, которая печатает полученные на вход параметры.

# %%
# определяем функцию тут

def print_function(x, y):
    print ("x is", x)
    print ("y is", y)

# %% [markdown]
# Вызываем функцию!

# %%
# вызываем функцию

print_function(100, 10)
# Out:
# x is 100
# y is 10

# %% [markdown]
# Функция может возвращать некоторый результат, для этого используется **return**:

# %%
# определяем функцию тут

def print_and_sum_function(x, y):
    print ("x is", x)
    print ("y is", y)
    
    return x+y

# %%
# тестируем функцию

z = print_and_sum_function(100, 10)

print ("z is", z)
# Out:
# x is 100
# y is 10
# z is 110

# %% [markdown]
# ### Глобальные и локальные переменные

# %% [markdown]
# Глобальные параметры определяются вне функции, а локальные существуют только в конкретной функции.

# %% [markdown]
# Глобальные параметры доступны внутри функций:

# %%
global_variable = 0

def change_variable_function():
    print ("Внутри функции:", global_variable, id(global_variable))
    print()
    
print ("Вне функции:", global_variable, id(global_variable))
print()

change_variable_function()
# Out:
# Вне функции: 0 4495545440
#
# Внутри функции: 0 4495545440

# %% [markdown]
# Все объявление переменных в функции считаются "локальными":

# %%
global_variable = 1000

def change_variable_function():
    print ("Внутри функции до изменения:", global_variable, id(global_variable))
    print()
    
    global_variable = 0
    
    print ("Внутри функции после изменения:",global_variable, id(global_variable))
    print()
    
print ("Вне функции:", global_variable, id(global_variable))
print()

change_variable_function()

print ("После функции:", global_variable, id(global_variable))
# Out:
# Вне функции: 1000 140691472727792
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-6-716516de08cd> in <module>
#      13 print()
#      14
# ---> 15 change_variable_function()
#      16
#      17 print ("После функции:", global_variable, id(global_variable))
#
# <ipython-input-6-716516de08cd> in change_variable_function()
#       2
#       3 def change_variable_function():
# ----> 4     print ("Внутри функции до изменения:", global_variable, id(global_variable))
#       5     print()
#       6
#
# UnboundLocalError: local variable 'global_variable' referenced before assignment

# %% [markdown]
# Чтобы сказать Python, что мы хотим менять глобальную переменную, можно использовать **global**:

# %%
global_variable = 0

def change_variable_function():
    global global_variable
    
    print ("Внутри функции до изменения:", global_variable, id(global_variable))
    print()
    
    global_variable = 1000
    
    print ("Внутри функции после изменения:",global_variable, id(global_variable))
    print()
    
print ("Вне функции:", global_variable, id(global_variable))
print()

change_variable_function()

print ("После функции:", global_variable, id(global_variable))
# Out:
# Вне функции: 0 4495545440
#
# Внутри функции до изменения: 0 4495545440
#
# Внутри функции после изменения: 1000 140691472726448
#
# После функции: 1000 140691472726448

# %% [markdown]
# ### Передача аргументов

# %% [markdown]
# Как вам известно, аргументы в функцию могут передаваться либо по значению, либо по ссылке (т.е. ссылка на участок в памяти):
#
# В Питоне все аргументы передаются по ссылке.

# %%
# определим тестовую функцию

def test_immutable_change(x):
    print ("id внутри функции до изменения: ", id(x))
    print ("значение внутри функции до изменения: ", x)
    print ()
    
    x = 0
    
    print ("id внутри функции после изменения: ", id(x))
    print ("значение внутри функции после изменения: ", x)
    
    return x


# проверим ее

y = 0

print ("id вне функции до вызова: ", id(y))
print ("значение вне функции до вызова: ", y)
print ()

test_immutable_change(y)

print ()
print ("id вне функции после вызова: ", id(y))
print ("значение вне функции после вызова: ", y)
# Out:
# id вне функции до вызова:  4495545440
# значение вне функции до вызова:  0
#
# id внутри функции до изменения:  4495545440
# значение внутри функции до изменения:  0
#
# id внутри функции после изменения:  4495545440
# значение внутри функции после изменения:  0
#
# id вне функции после вызова:  4495545440
# значение вне функции после вызова:  0

# %% [markdown]
# Однако, когда вы передаете mutable типы, то могут возникать так называемые "побочные эффекты":

# %%
# определим тестовую функцию

def test_mutable_change(x):
    print ("id внутри функции до изменения: ", id(x))
    print ("значение внутри функции до изменения: ", x)
    print ()
    
    x[0] = 2000
    
    print ("id внутри функции после изменения: ", id(x))
    print ("значение внутри функции после изменения: ", x)
    
    return x


# проверим ее

y = [1, 2, 3, 4]

print ("id вне функции до вызова: ", id(y))
print ("значение вне функции до вызова: ", y)
print ()

test_mutable_change(y)

print ()
print ("id вне функции после вызова: ", id(y))
print ("значение вне функции после вызова: ", y)
# Out:
# id вне функции до вызова:  140691472780576
# значение вне функции до вызова:  [1, 2, 3, 4]
#
# id внутри функции до изменения:  140691472780576
# значение внутри функции до изменения:  [1, 2, 3, 4]
#
# id внутри функции после изменения:  140691472780576
# значение внутри функции после изменения:  [2000, 2, 3, 4]
#
# id вне функции после вызова:  140691472780576
# значение вне функции после вызова:  [2000, 2, 3, 4]

# %% [markdown]
# ### Типы аргументов

# %% [markdown]
# #### Обязательные

# %% [markdown]
# Те аргументы, котрые обязательно передаются в функцию в определенном порядке

# %%
def print_function(x, y, z):
    print ("x is", x)
    print ("y is", y)
    print ("z is", z)

# %%
print_function(1, 10, 100)
# Out:
# x is 1
# y is 10
# z is 100

# %% [markdown]
# Мы не можем передать меньше аргументов:

# %%
print_function(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-2133c50d55ac> in <module>
# ----> 1 print_function(1)
#
# TypeError: print_function() missing 2 required positional arguments: 'y' and 'z'

# %% [markdown]
# Можно передавать аргументы в любом порядке:

# %%
print_function(1, z=10, y=-1)
# Out:
# x is 1
# y is -1
# z is 10

# %% [markdown]
# ####  Аргументы с дефолтным значением

# %% [markdown]
# Можно задать дефолтное значение:

# %%
def print_function(x, y=100):
    print ("x is", x)
    print ("y is", y)

# %%
def my_append(lst=[9, 8, 7]):
    lst.append(0)
    return lst

# %%
lst = [1, 2, 3]
print(my_append(lst))
# Out:
# [1, 2, 3, 0]

# %%
my_append()
# Out:
# [9, 8, 7, 0]

# %%
lst = [1, 2, 3]
print(my_append(lst))
# Out:
# [1, 2, 3, 0]

# %%
my_append()
# Out:
# [9, 8, 7, 0, 0]

# %%
print_function(10)
# Out:
# x is 10
# y is 100

# %%
print_function(0, 0)
# Out:
# x is 0
# y is 0

# %% [markdown]
# #### Аргументы с переменной длиной

# %%
def length_varying_print_functions(x, y=100, *args):
    print ("x is", x)
    print ("y is", y)
    print ("args is", args)

# %%
length_varying_print_functions(10, 11, 12, 13)
# Out:
# x is 10
# y is 11
# args is (12, 13)

# %%
def length_varying_kwargs_print_functions(x, y=100, *args, **kwargs):
    print ("x is", x)
    print ("y is", y)
    print ("args is", args)
    print ("kwargs is", kwargs)

# %%
length_varying_kwargs_print_functions(10, 11, 12, 13)
# Out:
# x is 10
# y is 11
# args is (12, 13)
# kwargs is {}

# %%
length_varying_kwargs_print_functions(10, 11, 12, vvv=13, z=18)
# Out:
# x is 10
# y is 11
# args is (12,)
# kwargs is {'vvv': 13, 'z': 18}

# %%
# а вот так нельзя!

def length_varying_kwargs_print_functions(**kwargs):
    print ("kwargs is", kwargs)
    
length_varying_kwargs_print_functions(1, 2, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-a35f56730fa8> in <module>
#       4     print ("kwargs is", kwargs)
#       5
# ----> 6 length_varying_kwargs_print_functions(1, 2, 3)
#
# TypeError: length_varying_kwargs_print_functions() takes 0 positional arguments but 3 were given

# %% [markdown]
# ### Рекурсивные функции

# %% [markdown]
# Функция внутри себя может вызывать другие функции.
#
# Важный частный случай - функция внутри себя вызывает **саму себя**.

# %%
# Давайте попробуем написать обычную функцию, которая вычисляет факториал числа


def factorial(n):
    factorial = 1
    
    for i in range(1, n+1):
        factorial *= i
        
    return factorial

# %%
factorial(10)
# Out:
# 3628800

# %% [markdown]
# Математически факториал можно написать в виде рекурсивной формулы:
#
# factorial(n+1) = factorial(n) * (n+1)

# %% [markdown]
# Советую начинать с того, чтобы продумывать, когда рекурсия заканчивается (т.е. что должно случиться, чтобы была "последняя" итерация):

# %%
# Давайте попробуем написать рекурсивную функцию, которая вычисляет факториал числа
import inspect

def recursive_factorial(n):
    print ("Вызов функции с n =", n)
#     print(len(inspect.stack()))
    
    if n == 0:
        return 1
    
    return n * recursive_factorial(n-1)

# %%
import sys
sys.getrecursionlimit()
# Out:
# 3000

# %%
recursive_factorial(2900)
# Out:
# Вызов функции с n = 2900
# Вызов функции с n = 2899
# Вызов функции с n = 2898
# Вызов функции с n = 2897
# Вызов функции с n = 2896
# Вызов функции с n = 2895
# Вызов функции с n = 2894
# Вызов функции с n = 2893
# Вызов функции с n = 2892
# Вызов функции с n = 2891
# Вызов функции с n = 2890
# Вызов функции с n = 2889
# Вызов функции с n = 2888
# Вызов функции с n = 2887
# Вызов функции с n = 2886
# Вызов функции с n = 2885
# Вызов функции с n = 2884
# Вызов функции с n = 2883
# Вызов функции с n = 2882
# Вызов функции с n = 2881
# Вызов функции с n = 2880
# Вызов функции с n = 2879
# Вызов функции с n = 2878
# Вызов функции с n = 2877
# Вызов функции с n = 2876
# Вызов функции с n = 2875
# Вызов функции с n = 2874
# Вызов функции с n = 2873
# Вызов функции с n = 2872
# Вызов функции с n = 2871
# Вызов функции с n = 2870
# Вызов функции с n = 2869
# Вызов функции с n = 2868
# Вызов функции с n = 2867
# Вызов функции с n = 2866
# Вызов функции с n = 2865
# Вызов функции с n = 2864
# Вызов функции с n = 2863
# Вызов функции с n = 2862
# Вызов функции с n = 2861
# Вызов функции с n = 2860
# Вызов функции с n = 2859
# Вызов функции с n = 2858
# Вызов функции с n = 2857
# Вызов функции с n = 2856
# Вызов функции с n = 2855
# Вызов функции с n = 2854
# Вызов функции с n = 2853
# Вызов функции с n = 2852
# Вызов функции с n = 2851
# Вызов функции с n = 2850
# Вызов функции с n = 2849
# Вызов функции с n = 2848
# Вызов функции с n = 2847
# Вызов функции с n = 2846
# Вызов функции с n = 2845
# Вызов функции с n = 2844
# Вызов функции с n = 2843
# Вызов функции с n = 2842
# Вызов функции с n = 2841
# Вызов функции с n = 2840
# Вызов функции с n = 2839
# Вызов функции с n = 2838
# Вызов функции с n = 2837
# Вызов функции с n = 2836
# Вызов функции с n = 2835
# Вызов функции с n = 2834
# Вызов функции с n = 2833
# Вызов функции с n = 2832
# Вызов функции с n = 2831
# Вызов функции с n = 2830
# Вызов функции с n = 2829
# Вызов функции с n = 2828
# Вызов функции с n = 2827
# Вызов функции с n = 2826
# Вызов функции с n = 2825
# Вызов функции с n = 2824
# Вызов функции с n = 2823
# Вызов функции с n = 2822
# Вызов функции с n = 2821
# Вызов функции с n = 2820
# Вызов функции с n = 2819
# Вызов функции с n = 2818
# Вызов функции с n = 2817
# Вызов функции с n = 2816
# Вызов функции с n = 2815
# Вызов функции с n = 2814
# Вызов функции с n = 2813
# Вызов функции с n = 2812
# Вызов функции с n = 2811
# Вызов функции с n = 2810
# Вызов функции с n = 2809
# Вызов функции с n = 2808
# Вызов функции с n = 2807
# Вызов функции с n = 2806
# Вызов функции с n = 2805
# Вызов функции с n = 2804
# Вызов функции с n = 2803
# Вызов функции с n = 2802
# Вызов функции с n = 2801
# Вызов функции с n = 2800
# Вызов функции с n = 2799
# Вызов функции с n = 2798
# Вызов функции с n = 2797
# Вызов функции с n = 2796
# Вызов функции с n = 2795
# Вызов функции с n = 2794
# Вызов функции с n = 2793
# Вызов функции с n = 2792
# Вызов функции с n = 2791
# Вызов функции с n = 2790
# Вызов функции с n = 2789
# Вызов функции с n = 2788
# Вызов функции с n = 2787
# Вызов функции с n = 2786
# Вызов функции с n = 2785
# Вызов функции с n = 2784
# Вызов функции с n = 2783
# Вызов функции с n = 2782
# Вызов функции с n = 2781
# Вызов функции с n = 2780
# Вызов функции с n = 2779
# Вызов функции с n = 2778
# Вызов функции с n = 2777
# Вызов функции с n = 2776
# Вызов функции с n = 2775
# Вызов функции с n = 2774
# Вызов функции с n = 2773
# Вызов функции с n = 2772
# Вызов функции с n = 2771
# Вызов функции с n = 2770
# Вызов функции с n = 2769
# Вызов функции с n = 2768
# Вызов функции с n = 2767
# Вызов функции с n = 2766
# Вызов функции с n = 2765
# Вызов функции с n = 2764
# Вызов функции с n = 2763
# Вызов функции с n = 2762
# Вызов функции с n = 2761
# Вызов функции с n = 2760
# Вызов функции с n = 2759
# Вызов функции с n = 2758
# Вызов функции с n = 2757
# Вызов функции с n = 2756
# Вызов функции с n = 2755
# Вызов функции с n = 2754
# Вызов функции с n = 2753
# Вызов функции с n = 2752
# Вызов функции с n = 2751
# Вызов функции с n = 2750
# Вызов функции с n = 2749
# Вызов функции с n = 2748
# Вызов функции с n = 2747
# Вызов функции с n = 2746
# Вызов функции с n = 2745
# Вызов функции с n = 2744
# Вызов функции с n = 2743
# Вызов функции с n = 2742
# Вызов функции с n = 2741
# Вызов функции с n = 2740
# Вызов функции с n = 2739
# Вызов функции с n = 2738
# Вызов функции с n = 2737
# Вызов функции с n = 2736
# Вызов функции с n = 2735
# Вызов функции с n = 2734
# Вызов функции с n = 2733
# Вызов функции с n = 2732
# Вызов функции с n = 2731
# Вызов функции с n = 2730
# Вызов функции с n = 2729
# Вызов функции с n = 2728
# Вызов функции с n = 2727
# Вызов функции с n = 2726
# Вызов функции с n = 2725
# Вызов функции с n = 2724
# Вызов функции с n = 2723
# Вызов функции с n = 2722
# Вызов функции с n = 2721
# Вызов функции с n = 2720
# Вызов функции с n = 2719
# Вызов функции с n = 2718
# Вызов функции с n = 2717
# Вызов функции с n = 2716
# Вызов функции с n = 2715
# Вызов функции с n = 2714
# Вызов функции с n = 2713
# Вызов функции с n = 2712
# Вызов функции с n = 2711
# Вызов функции с n = 2710
# Вызов функции с n = 2709
# Вызов функции с n = 2708
# Вызов функции с n = 2707
# Вызов функции с n = 2706
# Вызов функции с n = 2705
# Вызов функции с n = 2704
# Вызов функции с n = 2703
# Вызов функции с n = 2702
# Вызов функции с n = 2701
# Вызов функции с n = 2700
# Вызов функции с n = 2699
# Вызов функции с n = 2698
# Вызов функции с n = 2697
# Вызов функции с n = 2696
# Вызов функции с n = 2695
# Вызов функции с n = 2694
# Вызов функции с n = 2693
# Вызов функции с n = 2692
# Вызов функции с n = 2691
# Вызов функции с n = 2690
# Вызов функции с n = 2689
# Вызов функции с n = 2688
# Вызов функции с n = 2687
# Вызов функции с n = 2686
# Вызов функции с n = 2685
# Вызов функции с n = 2684
# Вызов функции с n = 2683
# Вызов функции с n = 2682
# Вызов функции с n = 2681
# Вызов функции с n = 2680
# Вызов функции с n = 2679
# Вызов функции с n = 2678
# Вызов функции с n = 2677
# Вызов функции с n = 2676
# Вызов функции с n = 2675
# Вызов функции с n = 2674
# Вызов функции с n = 2673
# Вызов функции с n = 2672
# Вызов функции с n = 2671
# Вызов функции с n = 2670
# Вызов функции с n = 2669
# Вызов функции с n = 2668
# Вызов функции с n = 2667
# Вызов функции с n = 2666
# Вызов функции с n = 2665
# Вызов функции с n = 2664
# Вызов функции с n = 2663
# Вызов функции с n = 2662
# Вызов функции с n = 2661
# Вызов функции с n = 2660
# Вызов функции с n = 2659
# Вызов функции с n = 2658
# Вызов функции с n = 2657
# Вызов функции с n = 2656
# Вызов функции с n = 2655
# Вызов функции с n = 2654
# Вызов функции с n = 2653
# Вызов функции с n = 2652
# Вызов функции с n = 2651
# Вызов функции с n = 2650
# Вызов функции с n = 2649
# Вызов функции с n = 2648
# Вызов функции с n = 2647
# Вызов функции с n = 2646
# Вызов функции с n = 2645
# Вызов функции с n = 2644
# Вызов функции с n = 2643
# Вызов функции с n = 2642
# Вызов функции с n = 2641
# Вызов функции с n = 2640
# Вызов функции с n = 2639
# Вызов функции с n = 2638
# Вызов функции с n = 2637
# Вызов функции с n = 2636
# Вызов функции с n = 2635
# Вызов функции с n = 2634
# Вызов функции с n = 2633
# Вызов функции с n = 2632
# Вызов функции с n = 2631
# Вызов функции с n = 2630
# Вызов функции с n = 2629
# Вызов функции с n = 2628
# Вызов функции с n = 2627
# Вызов функции с n = 2626
# Вызов функции с n = 2625
# Вызов функции с n = 2624
# Вызов функции с n = 2623
# Вызов функции с n = 2622
# Вызов функции с n = 2621
# Вызов функции с n = 2620
# Вызов функции с n = 2619
# Вызов функции с n = 2618
# Вызов функции с n = 2617
# Вызов функции с n = 2616
# Вызов функции с n = 2615
# Вызов функции с n = 2614
# Вызов функции с n = 2613
# Вызов функции с n = 2612
# Вызов функции с n = 2611
# Вызов функции с n = 2610
# Вызов функции с n = 2609
# Вызов функции с n = 2608
# Вызов функции с n = 2607
# Вызов функции с n = 2606
# Вызов функции с n = 2605
# Вызов функции с n = 2604
# Вызов функции с n = 2603
# Вызов функции с n = 2602
# Вызов функции с n = 2601
# Вызов функции с n = 2600
# Вызов функции с n = 2599
# Вызов функции с n = 2598
# Вызов функции с n = 2597
# Вызов функции с n = 2596
# Вызов функции с n = 2595
# Вызов функции с n = 2594
# Вызов функции с n = 2593
# Вызов функции с n = 2592
# Вызов функции с n = 2591
# Вызов функции с n = 2590
# Вызов функции с n = 2589
# Вызов функции с n = 2588
# Вызов функции с n = 2587
# Вызов функции с n = 2586
# Вызов функции с n = 2585
# Вызов функции с n = 2584
# Вызов функции с n = 2583
# Вызов функции с n = 2582
# Вызов функции с n = 2581
# Вызов функции с n = 2580
# Вызов функции с n = 2579
# Вызов функции с n = 2578
# Вызов функции с n = 2577
# Вызов функции с n = 2576
# Вызов функции с n = 2575
# Вызов функции с n = 2574
# Вызов функции с n = 2573
# Вызов функции с n = 2572
# Вызов функции с n = 2571
# Вызов функции с n = 2570
# Вызов функции с n = 2569
# Вызов функции с n = 2568
# Вызов функции с n = 2567
# Вызов функции с n = 2566
# Вызов функции с n = 2565
# Вызов функции с n = 2564
# Вызов функции с n = 2563
# Вызов функции с n = 2562
# Вызов функции с n = 2561
# Вызов функции с n = 2560
# Вызов функции с n = 2559
# Вызов функции с n = 2558
# Вызов функции с n = 2557
# Вызов функции с n = 2556
# Вызов функции с n = 2555
# Вызов функции с n = 2554
# Вызов функции с n = 2553
# Вызов функции с n = 2552
# Вызов функции с n = 2551
# Вызов функции с n = 2550
# Вызов функции с n = 2549
# Вызов функции с n = 2548
# Вызов функции с n = 2547
# Вызов функции с n = 2546
# Вызов функции с n = 2545
# Вызов функции с n = 2544
# Вызов функции с n = 2543
# Вызов функции с n = 2542
# Вызов функции с n = 2541
# Вызов функции с n = 2540
# Вызов функции с n = 2539
# Вызов функции с n = 2538
# Вызов функции с n = 2537
# Вызов функции с n = 2536
# Вызов функции с n = 2535
# Вызов функции с n = 2534
# Вызов функции с n = 2533
# Вызов функции с n = 2532
# Вызов функции с n = 2531
# Вызов функции с n = 2530
# Вызов функции с n = 2529
# Вызов функции с n = 2528
# Вызов функции с n = 2527
# Вызов функции с n = 2526
# Вызов функции с n = 2525
# Вызов функции с n = 2524
# Вызов функции с n = 2523
# Вызов функции с n = 2522
# Вызов функции с n = 2521
# Вызов функции с n = 2520
# Вызов функции с n = 2519
# Вызов функции с n = 2518
# Вызов функции с n = 2517
# Вызов функции с n = 2516
# Вызов функции с n = 2515
# Вызов функции с n = 2514
# Вызов функции с n = 2513
# Вызов функции с n = 2512
# Вызов функции с n = 2511
# Вызов функции с n = 2510
# Вызов функции с n = 2509
# Вызов функции с n = 2508
# Вызов функции с n = 2507
# Вызов функции с n = 2506
# Вызов функции с n = 2505
# Вызов функции с n = 2504
# Вызов функции с n = 2503
# Вызов функции с n = 2502
# Вызов функции с n = 2501
# Вызов функции с n = 2500
# Вызов функции с n = 2499
# Вызов функции с n = 2498
# Вызов функции с n = 2497
# Вызов функции с n = 2496
# Вызов функции с n = 2495
# Вызов функции с n = 2494
# Вызов функции с n = 2493
# Вызов функции с n = 2492
# Вызов функции с n = 2491
# Вызов функции с n = 2490
# Вызов функции с n = 2489
# Вызов функции с n = 2488
# Вызов функции с n = 2487
# Вызов функции с n = 2486
# Вызов функции с n = 2485
# Вызов функции с n = 2484
# Вызов функции с n = 2483
# Вызов функции с n = 2482
# Вызов функции с n = 2481
# Вызов функции с n = 2480
# Вызов функции с n = 2479
# Вызов функции с n = 2478
# Вызов функции с n = 2477
# Вызов функции с n = 2476
# Вызов функции с n = 2475
# Вызов функции с n = 2474
# Вызов функции с n = 2473
# Вызов функции с n = 2472
# Вызов функции с n = 2471
# Вызов функции с n = 2470
# Вызов функции с n = 2469
# Вызов функции с n = 2468
# Вызов функции с n = 2467
# Вызов функции с n = 2466
# Вызов функции с n = 2465
# Вызов функции с n = 2464
# Вызов функции с n = 2463
# Вызов функции с n = 2462
# Вызов функции с n = 2461
# Вызов функции с n = 2460
# Вызов функции с n = 2459
# Вызов функции с n = 2458
# Вызов функции с n = 2457
# Вызов функции с n = 2456
# Вызов функции с n = 2455
# Вызов функции с n = 2454
# Вызов функции с n = 2453
# Вызов функции с n = 2452
# Вызов функции с n = 2451
# Вызов функции с n = 2450
# Вызов функции с n = 2449
# Вызов функции с n = 2448
# Вызов функции с n = 2447
# Вызов функции с n = 2446
# Вызов функции с n = 2445
# Вызов функции с n = 2444
# Вызов функции с n = 2443
# Вызов функции с n = 2442
# Вызов функции с n = 2441
# Вызов функции с n = 2440
# Вызов функции с n = 2439
# Вызов функции с n = 2438
# Вызов функции с n = 2437
# Вызов функции с n = 2436
# Вызов функции с n = 2435
# Вызов функции с n = 2434
# Вызов функции с n = 2433
# Вызов функции с n = 2432
# Вызов функции с n = 2431
# Вызов функции с n = 2430
# Вызов функции с n = 2429
# Вызов функции с n = 2428
# Вызов функции с n = 2427
# Вызов функции с n = 2426
# Вызов функции с n = 2425
# Вызов функции с n = 2424
# Вызов функции с n = 2423
# Вызов функции с n = 2422
# Вызов функции с n = 2421
# Вызов функции с n = 2420
# Вызов функции с n = 2419
# Вызов функции с n = 2418
# Вызов функции с n = 2417
# Вызов функции с n = 2416
# Вызов функции с n = 2415
# Вызов функции с n = 2414
# Вызов функции с n = 2413
# Вызов функции с n = 2412
# Вызов функции с n = 2411
# Вызов функции с n = 2410
# Вызов функции с n = 2409
# Вызов функции с n = 2408
# Вызов функции с n = 2407
# Вызов функции с n = 2406
# Вызов функции с n = 2405
# Вызов функции с n = 2404
# Вызов функции с n = 2403
# Вызов функции с n = 2402
# Вызов функции с n = 2401
# Вызов функции с n = 2400
# Вызов функции с n = 2399
# Вызов функции с n = 2398
# Вызов функции с n = 2397
# Вызов функции с n = 2396
# Вызов функции с n = 2395
# Вызов функции с n = 2394
# Вызов функции с n = 2393
# Вызов функции с n = 2392
# Вызов функции с n = 2391
# Вызов функции с n = 2390
# Вызов функции с n = 2389
# Вызов функции с n = 2388
# Вызов функции с n = 2387
# Вызов функции с n = 2386
# Вызов функции с n = 2385
# Вызов функции с n = 2384
# Вызов функции с n = 2383
# Вызов функции с n = 2382
# Вызов функции с n = 2381
# Вызов функции с n = 2380
# Вызов функции с n = 2379
# Вызов функции с n = 2378
# Вызов функции с n = 2377
# Вызов функции с n = 2376
# Вызов функции с n = 2375
# Вызов функции с n = 2374
# Вызов функции с n = 2373
# Вызов функции с n = 2372
# Вызов функции с n = 2371
# Вызов функции с n = 2370
# Вызов функции с n = 2369
# Вызов функции с n = 2368
# Вызов функции с n = 2367
# Вызов функции с n = 2366
# Вызов функции с n = 2365
# Вызов функции с n = 2364
# Вызов функции с n = 2363
# Вызов функции с n = 2362
# Вызов функции с n = 2361
# Вызов функции с n = 2360
# Вызов функции с n = 2359
# Вызов функции с n = 2358
# Вызов функции с n = 2357
# Вызов функции с n = 2356
# Вызов функции с n = 2355
# Вызов функции с n = 2354
# Вызов функции с n = 2353
# Вызов функции с n = 2352
# Вызов функции с n = 2351
# Вызов функции с n = 2350
# Вызов функции с n = 2349
# Вызов функции с n = 2348
# Вызов функции с n = 2347
# Вызов функции с n = 2346
# Вызов функции с n = 2345
# Вызов функции с n = 2344
# Вызов функции с n = 2343
# Вызов функции с n = 2342
# Вызов функции с n = 2341
# Вызов функции с n = 2340
# Вызов функции с n = 2339
# Вызов функции с n = 2338
# Вызов функции с n = 2337
# Вызов функции с n = 2336
# Вызов функции с n = 2335
# Вызов функции с n = 2334
# Вызов функции с n = 2333
# Вызов функции с n = 2332
# Вызов функции с n = 2331
# Вызов функции с n = 2330
# Вызов функции с n = 2329
# Вызов функции с n = 2328
# Вызов функции с n = 2327
# Вызов функции с n = 2326
# Вызов функции с n = 2325
# Вызов функции с n = 2324
# Вызов функции с n = 2323
# Вызов функции с n = 2322
# Вызов функции с n = 2321
# Вызов функции с n = 2320
# Вызов функции с n = 2319
# Вызов функции с n = 2318
# Вызов функции с n = 2317
# Вызов функции с n = 2316
# Вызов функции с n = 2315
# Вызов функции с n = 2314
# Вызов функции с n = 2313
# Вызов функции с n = 2312
# Вызов функции с n = 2311
# Вызов функции с n = 2310
# Вызов функции с n = 2309
# Вызов функции с n = 2308
# Вызов функции с n = 2307
# Вызов функции с n = 2306
# Вызов функции с n = 2305
# Вызов функции с n = 2304
# Вызов функции с n = 2303
# Вызов функции с n = 2302
# Вызов функции с n = 2301
# Вызов функции с n = 2300
# Вызов функции с n = 2299
# Вызов функции с n = 2298
# Вызов функции с n = 2297
# Вызов функции с n = 2296
# Вызов функции с n = 2295
# Вызов функции с n = 2294
# Вызов функции с n = 2293
# Вызов функции с n = 2292
# Вызов функции с n = 2291
# Вызов функции с n = 2290
# Вызов функции с n = 2289
# Вызов функции с n = 2288
# Вызов функции с n = 2287
# Вызов функции с n = 2286
# Вызов функции с n = 2285
# Вызов функции с n = 2284
# Вызов функции с n = 2283
# Вызов функции с n = 2282
# Вызов функции с n = 2281
# Вызов функции с n = 2280
# Вызов функции с n = 2279
# Вызов функции с n = 2278
# Вызов функции с n = 2277
# Вызов функции с n = 2276
# Вызов функции с n = 2275
# Вызов функции с n = 2274
# Вызов функции с n = 2273
# Вызов функции с n = 2272
# Вызов функции с n = 2271
# Вызов функции с n = 2270
# Вызов функции с n = 2269
# Вызов функции с n = 2268
# Вызов функции с n = 2267
# Вызов функции с n = 2266
# Вызов функции с n = 2265
# Вызов функции с n = 2264
# Вызов функции с n = 2263
# Вызов функции с n = 2262
# Вызов функции с n = 2261
# Вызов функции с n = 2260
# Вызов функции с n = 2259
# Вызов функции с n = 2258
# Вызов функции с n = 2257
# Вызов функции с n = 2256
# Вызов функции с n = 2255
# Вызов функции с n = 2254
# Вызов функции с n = 2253
# Вызов функции с n = 2252
# Вызов функции с n = 2251
# Вызов функции с n = 2250
# Вызов функции с n = 2249
# Вызов функции с n = 2248
# Вызов функции с n = 2247
# Вызов функции с n = 2246
# Вызов функции с n = 2245
# Вызов функции с n = 2244
# Вызов функции с n = 2243
# Вызов функции с n = 2242
# Вызов функции с n = 2241
# Вызов функции с n = 2240
# Вызов функции с n = 2239
# Вызов функции с n = 2238
# Вызов функции с n = 2237
# Вызов функции с n = 2236
# Вызов функции с n = 2235
# Вызов функции с n = 2234
# Вызов функции с n = 2233
# Вызов функции с n = 2232
# Вызов функции с n = 2231
# Вызов функции с n = 2230
# Вызов функции с n = 2229
# Вызов функции с n = 2228
# Вызов функции с n = 2227
# Вызов функции с n = 2226
# Вызов функции с n = 2225
# Вызов функции с n = 2224
# Вызов функции с n = 2223
# Вызов функции с n = 2222
# Вызов функции с n = 2221
# Вызов функции с n = 2220
# Вызов функции с n = 2219
# Вызов функции с n = 2218
# Вызов функции с n = 2217
# Вызов функции с n = 2216
# Вызов функции с n = 2215
# Вызов функции с n = 2214
# Вызов функции с n = 2213
# Вызов функции с n = 2212
# Вызов функции с n = 2211
# Вызов функции с n = 2210
# Вызов функции с n = 2209
# Вызов функции с n = 2208
# Вызов функции с n = 2207
# Вызов функции с n = 2206
# Вызов функции с n = 2205
# Вызов функции с n = 2204
# Вызов функции с n = 2203
# Вызов функции с n = 2202
# Вызов функции с n = 2201
# Вызов функции с n = 2200
# Вызов функции с n = 2199
# Вызов функции с n = 2198
# Вызов функции с n = 2197
# Вызов функции с n = 2196
# Вызов функции с n = 2195
# Вызов функции с n = 2194
# Вызов функции с n = 2193
# Вызов функции с n = 2192
# Вызов функции с n = 2191
# Вызов функции с n = 2190
# Вызов функции с n = 2189
# Вызов функции с n = 2188
# Вызов функции с n = 2187
# Вызов функции с n = 2186
# Вызов функции с n = 2185
# Вызов функции с n = 2184
# Вызов функции с n = 2183
# Вызов функции с n = 2182
# Вызов функции с n = 2181
# Вызов функции с n = 2180
# Вызов функции с n = 2179
# Вызов функции с n = 2178
# Вызов функции с n = 2177
# Вызов функции с n = 2176
# Вызов функции с n = 2175
# Вызов функции с n = 2174
# Вызов функции с n = 2173
# Вызов функции с n = 2172
# Вызов функции с n = 2171
# Вызов функции с n = 2170
# Вызов функции с n = 2169
# Вызов функции с n = 2168
# Вызов функции с n = 2167
# Вызов функции с n = 2166
# Вызов функции с n = 2165
# Вызов функции с n = 2164
# Вызов функции с n = 2163
# Вызов функции с n = 2162
# Вызов функции с n = 2161
# Вызов функции с n = 2160
# Вызов функции с n = 2159
# Вызов функции с n = 2158
# Вызов функции с n = 2157
# Вызов функции с n = 2156
# Вызов функции с n = 2155
# Вызов функции с n = 2154
# Вызов функции с n = 2153
# Вызов функции с n = 2152
# Вызов функции с n = 2151
# Вызов функции с n = 2150
# Вызов функции с n = 2149
# Вызов функции с n = 2148
# Вызов функции с n = 2147
# Вызов функции с n = 2146
# Вызов функции с n = 2145
# Вызов функции с n = 2144
# Вызов функции с n = 2143
# Вызов функции с n = 2142
# Вызов функции с n = 2141
# Вызов функции с n = 2140
# Вызов функции с n = 2139
# Вызов функции с n = 2138
# Вызов функции с n = 2137
# Вызов функции с n = 2136
# Вызов функции с n = 2135
# Вызов функции с n = 2134
# Вызов функции с n = 2133
# Вызов функции с n = 2132
# Вызов функции с n = 2131
# Вызов функции с n = 2130
# Вызов функции с n = 2129
# Вызов функции с n = 2128
# Вызов функции с n = 2127
# Вызов функции с n = 2126
# Вызов функции с n = 2125
# Вызов функции с n = 2124
# Вызов функции с n = 2123
# Вызов функции с n = 2122
# Вызов функции с n = 2121
# Вызов функции с n = 2120
# Вызов функции с n = 2119
# Вызов функции с n = 2118
# Вызов функции с n = 2117
# Вызов функции с n = 2116
# Вызов функции с n = 2115
# Вызов функции с n = 2114
# Вызов функции с n = 2113
# Вызов функции с n = 2112
# Вызов функции с n = 2111
# Вызов функции с n = 2110
# Вызов функции с n = 2109
# Вызов функции с n = 2108
# Вызов функции с n = 2107
# Вызов функции с n = 2106
# Вызов функции с n = 2105
# Вызов функции с n = 2104
# Вызов функции с n = 2103
# Вызов функции с n = 2102
# Вызов функции с n = 2101
# Вызов функции с n = 2100
# Вызов функции с n = 2099
# Вызов функции с n = 2098
# Вызов функции с n = 2097
# Вызов функции с n = 2096
# Вызов функции с n = 2095
# Вызов функции с n = 2094
# Вызов функции с n = 2093
# Вызов функции с n = 2092
# Вызов функции с n = 2091
# Вызов функции с n = 2090
# Вызов функции с n = 2089
# Вызов функции с n = 2088
# Вызов функции с n = 2087
# Вызов функции с n = 2086
# Вызов функции с n = 2085
# Вызов функции с n = 2084
# Вызов функции с n = 2083
# Вызов функции с n = 2082
# Вызов функции с n = 2081
# Вызов функции с n = 2080
# Вызов функции с n = 2079
# Вызов функции с n = 2078
# Вызов функции с n = 2077
# Вызов функции с n = 2076
# Вызов функции с n = 2075
# Вызов функции с n = 2074
# Вызов функции с n = 2073
# Вызов функции с n = 2072
# Вызов функции с n = 2071
# Вызов функции с n = 2070
# Вызов функции с n = 2069
# Вызов функции с n = 2068
# Вызов функции с n = 2067
# Вызов функции с n = 2066
# Вызов функции с n = 2065
# Вызов функции с n = 2064
# Вызов функции с n = 2063
# Вызов функции с n = 2062
# Вызов функции с n = 2061
# Вызов функции с n = 2060
# Вызов функции с n = 2059
# Вызов функции с n = 2058
# Вызов функции с n = 2057
# Вызов функции с n = 2056
# Вызов функции с n = 2055
# Вызов функции с n = 2054
# Вызов функции с n = 2053
# Вызов функции с n = 2052
# Вызов функции с n = 2051
# Вызов функции с n = 2050
# Вызов функции с n = 2049
# Вызов функции с n = 2048
# Вызов функции с n = 2047
# Вызов функции с n = 2046
# Вызов функции с n = 2045
# Вызов функции с n = 2044
# Вызов функции с n = 2043
# Вызов функции с n = 2042
# Вызов функции с n = 2041
# Вызов функции с n = 2040
# Вызов функции с n = 2039
# Вызов функции с n = 2038
# Вызов функции с n = 2037
# Вызов функции с n = 2036
# Вызов функции с n = 2035
# Вызов функции с n = 2034
# Вызов функции с n = 2033
# Вызов функции с n = 2032
# Вызов функции с n = 2031
# Вызов функции с n = 2030
# Вызов функции с n = 2029
# Вызов функции с n = 2028
# Вызов функции с n = 2027
# Вызов функции с n = 2026
# Вызов функции с n = 2025
# Вызов функции с n = 2024
# Вызов функции с n = 2023
# Вызов функции с n = 2022
# Вызов функции с n = 2021
# Вызов функции с n = 2020
# Вызов функции с n = 2019
# Вызов функции с n = 2018
# Вызов функции с n = 2017
# Вызов функции с n = 2016
# Вызов функции с n = 2015
# Вызов функции с n = 2014
# Вызов функции с n = 2013
# Вызов функции с n = 2012
# Вызов функции с n = 2011
# Вызов функции с n = 2010
# Вызов функции с n = 2009
# Вызов функции с n = 2008
# Вызов функции с n = 2007
# Вызов функции с n = 2006
# Вызов функции с n = 2005
# Вызов функции с n = 2004
# Вызов функции с n = 2003
# Вызов функции с n = 2002
# Вызов функции с n = 2001
# Вызов функции с n = 2000
# Вызов функции с n = 1999
# Вызов функции с n = 1998
# Вызов функции с n = 1997
# Вызов функции с n = 1996
# Вызов функции с n = 1995
# Вызов функции с n = 1994
# Вызов функции с n = 1993
# Вызов функции с n = 1992
# Вызов функции с n = 1991
# Вызов функции с n = 1990
# Вызов функции с n = 1989
# Вызов функции с n = 1988
# Вызов функции с n = 1987
# Вызов функции с n = 1986
# Вызов функции с n = 1985
# Вызов функции с n = 1984
# Вызов функции с n = 1983
# Вызов функции с n = 1982
# Вызов функции с n = 1981
# Вызов функции с n = 1980
# Вызов функции с n = 1979
# Вызов функции с n = 1978
# Вызов функции с n = 1977
# Вызов функции с n = 1976
# Вызов функции с n = 1975
# Вызов функции с n = 1974
# Вызов функции с n = 1973
# Вызов функции с n = 1972
# Вызов функции с n = 1971
# Вызов функции с n = 1970
# Вызов функции с n = 1969
# Вызов функции с n = 1968
# Вызов функции с n = 1967
# Вызов функции с n = 1966
# Вызов функции с n = 1965
# Вызов функции с n = 1964
# Вызов функции с n = 1963
# Вызов функции с n = 1962
# Вызов функции с n = 1961
# Вызов функции с n = 1960
# Вызов функции с n = 1959
# Вызов функции с n = 1958
# Вызов функции с n = 1957
# Вызов функции с n = 1956
# Вызов функции с n = 1955
# Вызов функции с n = 1954
# Вызов функции с n = 1953
# Вызов функции с n = 1952
# Вызов функции с n = 1951
# Вызов функции с n = 1950
# Вызов функции с n = 1949
# Вызов функции с n = 1948
# Вызов функции с n = 1947
# Вызов функции с n = 1946
# Вызов функции с n = 1945
# Вызов функции с n = 1944
# Вызов функции с n = 1943
# Вызов функции с n = 1942
# Вызов функции с n = 1941
# Вызов функции с n = 1940
# Вызов функции с n = 1939
# Вызов функции с n = 1938
# Вызов функции с n = 1937
# Вызов функции с n = 1936
# Вызов функции с n = 1935
# Вызов функции с n = 1934
# Вызов функции с n = 1933
# Вызов функции с n = 1932
# Вызов функции с n = 1931
# Вызов функции с n = 1930
# Вызов функции с n = 1929
# Вызов функции с n = 1928
# Вызов функции с n = 1927
# Вызов функции с n = 1926
# Вызов функции с n = 1925
# Вызов функции с n = 1924
# Вызов функции с n = 1923
# Вызов функции с n = 1922
# Вызов функции с n = 1921
# Вызов функции с n = 1920
# Вызов функции с n = 1919
# Вызов функции с n = 1918
# Вызов функции с n = 1917
# Вызов функции с n = 1916
# Вызов функции с n = 1915
# Вызов функции с n = 1914
# Вызов функции с n = 1913
# Вызов функции с n = 1912
# Вызов функции с n = 1911
# Вызов функции с n = 1910
# Вызов функции с n = 1909
# Вызов функции с n = 1908
# Вызов функции с n = 1907
# Вызов функции с n = 1906
# Вызов функции с n = 1905
# Вызов функции с n = 1904
# Вызов функции с n = 1903
# Вызов функции с n = 1902
# Вызов функции с n = 1901
# Вызов функции с n = 1900
# Вызов функции с n = 1899
# Вызов функции с n = 1898
# Вызов функции с n = 1897
# Вызов функции с n = 1896
# Вызов функции с n = 1895
# Вызов функции с n = 1894
# Вызов функции с n = 1893
# Вызов функции с n = 1892
# Вызов функции с n = 1891
# Вызов функции с n = 1890
# Вызов функции с n = 1889
# Вызов функции с n = 1888
# Вызов функции с n = 1887
# Вызов функции с n = 1886
# Вызов функции с n = 1885
# Вызов функции с n = 1884
# Вызов функции с n = 1883
# Вызов функции с n = 1882
# Вызов функции с n = 1881
# Вызов функции с n = 1880
# Вызов функции с n = 1879
# Вызов функции с n = 1878
# Вызов функции с n = 1877
# Вызов функции с n = 1876
# Вызов функции с n = 1875
# Вызов функции с n = 1874
# Вызов функции с n = 1873
# Вызов функции с n = 1872
# Вызов функции с n = 1871
# Вызов функции с n = 1870
# Вызов функции с n = 1869
# Вызов функции с n = 1868
# Вызов функции с n = 1867
# Вызов функции с n = 1866
# Вызов функции с n = 1865
# Вызов функции с n = 1864
# Вызов функции с n = 1863
# Вызов функции с n = 1862
# Вызов функции с n = 1861
# Вызов функции с n = 1860
# Вызов функции с n = 1859
# Вызов функции с n = 1858
# Вызов функции с n = 1857
# Вызов функции с n = 1856
# Вызов функции с n = 1855
# Вызов функции с n = 1854
# Вызов функции с n = 1853
# Вызов функции с n = 1852
# Вызов функции с n = 1851
# Вызов функции с n = 1850
# Вызов функции с n = 1849
# Вызов функции с n = 1848
# Вызов функции с n = 1847
# Вызов функции с n = 1846
# Вызов функции с n = 1845
# Вызов функции с n = 1844
# Вызов функции с n = 1843
# Вызов функции с n = 1842
# Вызов функции с n = 1841
# Вызов функции с n = 1840
# Вызов функции с n = 1839
# Вызов функции с n = 1838
# Вызов функции с n = 1837
# Вызов функции с n = 1836
# Вызов функции с n = 1835
# Вызов функции с n = 1834
# Вызов функции с n = 1833
# Вызов функции с n = 1832
# Вызов функции с n = 1831
# Вызов функции с n = 1830
# Вызов функции с n = 1829
# Вызов функции с n = 1828
# Вызов функции с n = 1827
# Вызов функции с n = 1826
# Вызов функции с n = 1825
# Вызов функции с n = 1824
# Вызов функции с n = 1823
# Вызов функции с n = 1822
# Вызов функции с n = 1821
# Вызов функции с n = 1820
# Вызов функции с n = 1819
# Вызов функции с n = 1818
# Вызов функции с n = 1817
# Вызов функции с n = 1816
# Вызов функции с n = 1815
# Вызов функции с n = 1814
# Вызов функции с n = 1813
# Вызов функции с n = 1812
# Вызов функции с n = 1811
# Вызов функции с n = 1810
# Вызов функции с n = 1809
# Вызов функции с n = 1808
# Вызов функции с n = 1807
# Вызов функции с n = 1806
# Вызов функции с n = 1805
# Вызов функции с n = 1804
# Вызов функции с n = 1803
# Вызов функции с n = 1802
# Вызов функции с n = 1801
# Вызов функции с n = 1800
# Вызов функции с n = 1799
# Вызов функции с n = 1798
# Вызов функции с n = 1797
# Вызов функции с n = 1796
# Вызов функции с n = 1795
# Вызов функции с n = 1794
# Вызов функции с n = 1793
# Вызов функции с n = 1792
# Вызов функции с n = 1791
# Вызов функции с n = 1790
# Вызов функции с n = 1789
# Вызов функции с n = 1788
# Вызов функции с n = 1787
# Вызов функции с n = 1786
# Вызов функции с n = 1785
# Вызов функции с n = 1784
# Вызов функции с n = 1783
# Вызов функции с n = 1782
# Вызов функции с n = 1781
# Вызов функции с n = 1780
# Вызов функции с n = 1779
# Вызов функции с n = 1778
# Вызов функции с n = 1777
# Вызов функции с n = 1776
# Вызов функции с n = 1775
# Вызов функции с n = 1774
# Вызов функции с n = 1773
# Вызов функции с n = 1772
# Вызов функции с n = 1771
# Вызов функции с n = 1770
# Вызов функции с n = 1769
# Вызов функции с n = 1768
# Вызов функции с n = 1767
# Вызов функции с n = 1766
# Вызов функции с n = 1765
# Вызов функции с n = 1764
# Вызов функции с n = 1763
# Вызов функции с n = 1762
# Вызов функции с n = 1761
# Вызов функции с n = 1760
# Вызов функции с n = 1759
# Вызов функции с n = 1758
# Вызов функции с n = 1757
# Вызов функции с n = 1756
# Вызов функции с n = 1755
# Вызов функции с n = 1754
# Вызов функции с n = 1753
# Вызов функции с n = 1752
# Вызов функции с n = 1751
# Вызов функции с n = 1750
# Вызов функции с n = 1749
# Вызов функции с n = 1748
# Вызов функции с n = 1747
# Вызов функции с n = 1746
# Вызов функции с n = 1745
# Вызов функции с n = 1744
# Вызов функции с n = 1743
# Вызов функции с n = 1742
# Вызов функции с n = 1741
# Вызов функции с n = 1740
# Вызов функции с n = 1739
# Вызов функции с n = 1738
# Вызов функции с n = 1737
# Вызов функции с n = 1736
# Вызов функции с n = 1735
# Вызов функции с n = 1734
# Вызов функции с n = 1733
# Вызов функции с n = 1732
# Вызов функции с n = 1731
# Вызов функции с n = 1730
# Вызов функции с n = 1729
# Вызов функции с n = 1728
# Вызов функции с n = 1727
# Вызов функции с n = 1726
# Вызов функции с n = 1725
# Вызов функции с n = 1724
# Вызов функции с n = 1723
# Вызов функции с n = 1722
# Вызов функции с n = 1721
# Вызов функции с n = 1720
# Вызов функции с n = 1719
# Вызов функции с n = 1718
# Вызов функции с n = 1717
# Вызов функции с n = 1716
# Вызов функции с n = 1715
# Вызов функции с n = 1714
# Вызов функции с n = 1713
# Вызов функции с n = 1712
# Вызов функции с n = 1711
# Вызов функции с n = 1710
# Вызов функции с n = 1709
# Вызов функции с n = 1708
# Вызов функции с n = 1707
# Вызов функции с n = 1706
# Вызов функции с n = 1705
# Вызов функции с n = 1704
# Вызов функции с n = 1703
# Вызов функции с n = 1702
# Вызов функции с n = 1701
# Вызов функции с n = 1700
# Вызов функции с n = 1699
# Вызов функции с n = 1698
# Вызов функции с n = 1697
# Вызов функции с n = 1696
# Вызов функции с n = 1695
# Вызов функции с n = 1694
# Вызов функции с n = 1693
# Вызов функции с n = 1692
# Вызов функции с n = 1691
# Вызов функции с n = 1690
# Вызов функции с n = 1689
# Вызов функции с n = 1688
# Вызов функции с n = 1687
# Вызов функции с n = 1686
# Вызов функции с n = 1685
# Вызов функции с n = 1684
# Вызов функции с n = 1683
# Вызов функции с n = 1682
# Вызов функции с n = 1681
# Вызов функции с n = 1680
# Вызов функции с n = 1679
# Вызов функции с n = 1678
# Вызов функции с n = 1677
# Вызов функции с n = 1676
# Вызов функции с n = 1675
# Вызов функции с n = 1674
# Вызов функции с n = 1673
# Вызов функции с n = 1672
# Вызов функции с n = 1671
# Вызов функции с n = 1670
# Вызов функции с n = 1669
# Вызов функции с n = 1668
# Вызов функции с n = 1667
# Вызов функции с n = 1666
# Вызов функции с n = 1665
# Вызов функции с n = 1664
# Вызов функции с n = 1663
# Вызов функции с n = 1662
# Вызов функции с n = 1661
# Вызов функции с n = 1660
# Вызов функции с n = 1659
# Вызов функции с n = 1658
# Вызов функции с n = 1657
# Вызов функции с n = 1656
# Вызов функции с n = 1655
# Вызов функции с n = 1654
# Вызов функции с n = 1653
# Вызов функции с n = 1652
# Вызов функции с n = 1651
# Вызов функции с n = 1650
# Вызов функции с n = 1649
# Вызов функции с n = 1648
# Вызов функции с n = 1647
# Вызов функции с n = 1646
# Вызов функции с n = 1645
# Вызов функции с n = 1644
# Вызов функции с n = 1643
# Вызов функции с n = 1642
# Вызов функции с n = 1641
# Вызов функции с n = 1640
# Вызов функции с n = 1639
# Вызов функции с n = 1638
# Вызов функции с n = 1637
# Вызов функции с n = 1636
# Вызов функции с n = 1635
# Вызов функции с n = 1634
# Вызов функции с n = 1633
# Вызов функции с n = 1632
# Вызов функции с n = 1631
# Вызов функции с n = 1630
# Вызов функции с n = 1629
# Вызов функции с n = 1628
# Вызов функции с n = 1627
# Вызов функции с n = 1626
# Вызов функции с n = 1625
# Вызов функции с n = 1624
# Вызов функции с n = 1623
# Вызов функции с n = 1622
# Вызов функции с n = 1621
# Вызов функции с n = 1620
# Вызов функции с n = 1619
# Вызов функции с n = 1618
# Вызов функции с n = 1617
# Вызов функции с n = 1616
# Вызов функции с n = 1615
# Вызов функции с n = 1614
# Вызов функции с n = 1613
# Вызов функции с n = 1612
# Вызов функции с n = 1611
# Вызов функции с n = 1610
# Вызов функции с n = 1609
# Вызов функции с n = 1608
# Вызов функции с n = 1607
# Вызов функции с n = 1606
# Вызов функции с n = 1605
# Вызов функции с n = 1604
# Вызов функции с n = 1603
# Вызов функции с n = 1602
# Вызов функции с n = 1601
# Вызов функции с n = 1600
# Вызов функции с n = 1599
# Вызов функции с n = 1598
# Вызов функции с n = 1597
# Вызов функции с n = 1596
# Вызов функции с n = 1595
# Вызов функции с n = 1594
# Вызов функции с n = 1593
# Вызов функции с n = 1592
# Вызов функции с n = 1591
# Вызов функции с n = 1590
# Вызов функции с n = 1589
# Вызов функции с n = 1588
# Вызов функции с n = 1587
# Вызов функции с n = 1586
# Вызов функции с n = 1585
# Вызов функции с n = 1584
# Вызов функции с n = 1583
# Вызов функции с n = 1582
# Вызов функции с n = 1581
# Вызов функции с n = 1580
# Вызов функции с n = 1579
# Вызов функции с n = 1578
# Вызов функции с n = 1577
# Вызов функции с n = 1576
# Вызов функции с n = 1575
# Вызов функции с n = 1574
# Вызов функции с n = 1573
# Вызов функции с n = 1572
# Вызов функции с n = 1571
# Вызов функции с n = 1570
# Вызов функции с n = 1569
# Вызов функции с n = 1568
# Вызов функции с n = 1567
# Вызов функции с n = 1566
# Вызов функции с n = 1565
# Вызов функции с n = 1564
# Вызов функции с n = 1563
# Вызов функции с n = 1562
# Вызов функции с n = 1561
# Вызов функции с n = 1560
# Вызов функции с n = 1559
# Вызов функции с n = 1558
# Вызов функции с n = 1557
# Вызов функции с n = 1556
# Вызов функции с n = 1555
# Вызов функции с n = 1554
# Вызов функции с n = 1553
# Вызов функции с n = 1552
# Вызов функции с n = 1551
# Вызов функции с n = 1550
# Вызов функции с n = 1549
# Вызов функции с n = 1548
# Вызов функции с n = 1547
# Вызов функции с n = 1546
# Вызов функции с n = 1545
# Вызов функции с n = 1544
# Вызов функции с n = 1543
# Вызов функции с n = 1542
# Вызов функции с n = 1541
# Вызов функции с n = 1540
# Вызов функции с n = 1539
# Вызов функции с n = 1538
# Вызов функции с n = 1537
# Вызов функции с n = 1536
# Вызов функции с n = 1535
# Вызов функции с n = 1534
# Вызов функции с n = 1533
# Вызов функции с n = 1532
# Вызов функции с n = 1531
# Вызов функции с n = 1530
# Вызов функции с n = 1529
# Вызов функции с n = 1528
# Вызов функции с n = 1527
# Вызов функции с n = 1526
# Вызов функции с n = 1525
# Вызов функции с n = 1524
# Вызов функции с n = 1523
# Вызов функции с n = 1522
# Вызов функции с n = 1521
# Вызов функции с n = 1520
# Вызов функции с n = 1519
# Вызов функции с n = 1518
# Вызов функции с n = 1517
# Вызов функции с n = 1516
# Вызов функции с n = 1515
# Вызов функции с n = 1514
# Вызов функции с n = 1513
# Вызов функции с n = 1512
# Вызов функции с n = 1511
# Вызов функции с n = 1510
# Вызов функции с n = 1509
# Вызов функции с n = 1508
# Вызов функции с n = 1507
# Вызов функции с n = 1506
# Вызов функции с n = 1505
# Вызов функции с n = 1504
# Вызов функции с n = 1503
# Вызов функции с n = 1502
# Вызов функции с n = 1501
# Вызов функции с n = 1500
# Вызов функции с n = 1499
# Вызов функции с n = 1498
# Вызов функции с n = 1497
# Вызов функции с n = 1496
# Вызов функции с n = 1495
# Вызов функции с n = 1494
# Вызов функции с n = 1493
# Вызов функции с n = 1492
# Вызов функции с n = 1491
# Вызов функции с n = 1490
# Вызов функции с n = 1489
# Вызов функции с n = 1488
# Вызов функции с n = 1487
# Вызов функции с n = 1486
# Вызов функции с n = 1485
# Вызов функции с n = 1484
# Вызов функции с n = 1483
# Вызов функции с n = 1482
# Вызов функции с n = 1481
# Вызов функции с n = 1480
# Вызов функции с n = 1479
# Вызов функции с n = 1478
# Вызов функции с n = 1477
# Вызов функции с n = 1476
# Вызов функции с n = 1475
# Вызов функции с n = 1474
# Вызов функции с n = 1473
# Вызов функции с n = 1472
# Вызов функции с n = 1471
# Вызов функции с n = 1470
# Вызов функции с n = 1469
# Вызов функции с n = 1468
# Вызов функции с n = 1467
# Вызов функции с n = 1466
# Вызов функции с n = 1465
# Вызов функции с n = 1464
# Вызов функции с n = 1463
# Вызов функции с n = 1462
# Вызов функции с n = 1461
# Вызов функции с n = 1460
# Вызов функции с n = 1459
# Вызов функции с n = 1458
# Вызов функции с n = 1457
# Вызов функции с n = 1456
# Вызов функции с n = 1455
# Вызов функции с n = 1454
# Вызов функции с n = 1453
# Вызов функции с n = 1452
# Вызов функции с n = 1451
# Вызов функции с n = 1450
# Вызов функции с n = 1449
# Вызов функции с n = 1448
# Вызов функции с n = 1447
# Вызов функции с n = 1446
# Вызов функции с n = 1445
# Вызов функции с n = 1444
# Вызов функции с n = 1443
# Вызов функции с n = 1442
# Вызов функции с n = 1441
# Вызов функции с n = 1440
# Вызов функции с n = 1439
# Вызов функции с n = 1438
# Вызов функции с n = 1437
# Вызов функции с n = 1436
# Вызов функции с n = 1435
# Вызов функции с n = 1434
# Вызов функции с n = 1433
# Вызов функции с n = 1432
# Вызов функции с n = 1431
# Вызов функции с n = 1430
# Вызов функции с n = 1429
# Вызов функции с n = 1428
# Вызов функции с n = 1427
# Вызов функции с n = 1426
# Вызов функции с n = 1425
# Вызов функции с n = 1424
# Вызов функции с n = 1423
# Вызов функции с n = 1422
# Вызов функции с n = 1421
# Вызов функции с n = 1420
# Вызов функции с n = 1419
# Вызов функции с n = 1418
# Вызов функции с n = 1417
# Вызов функции с n = 1416
# Вызов функции с n = 1415
# Вызов функции с n = 1414
# Вызов функции с n = 1413
# Вызов функции с n = 1412
# Вызов функции с n = 1411
# Вызов функции с n = 1410
# Вызов функции с n = 1409
# Вызов функции с n = 1408
# Вызов функции с n = 1407
# Вызов функции с n = 1406
# Вызов функции с n = 1405
# Вызов функции с n = 1404
# Вызов функции с n = 1403
# Вызов функции с n = 1402
# Вызов функции с n = 1401
# Вызов функции с n = 1400
# Вызов функции с n = 1399
# Вызов функции с n = 1398
# Вызов функции с n = 1397
# Вызов функции с n = 1396
# Вызов функции с n = 1395
# Вызов функции с n = 1394
# Вызов функции с n = 1393
# Вызов функции с n = 1392
# Вызов функции с n = 1391
# Вызов функции с n = 1390
# Вызов функции с n = 1389
# Вызов функции с n = 1388
# Вызов функции с n = 1387
# Вызов функции с n = 1386
# Вызов функции с n = 1385
# Вызов функции с n = 1384
# Вызов функции с n = 1383
# Вызов функции с n = 1382
# Вызов функции с n = 1381
# Вызов функции с n = 1380
# Вызов функции с n = 1379
# Вызов функции с n = 1378
# Вызов функции с n = 1377
# Вызов функции с n = 1376
# Вызов функции с n = 1375
# Вызов функции с n = 1374
# Вызов функции с n = 1373
# Вызов функции с n = 1372
# Вызов функции с n = 1371
# Вызов функции с n = 1370
# Вызов функции с n = 1369
# Вызов функции с n = 1368
# Вызов функции с n = 1367
# Вызов функции с n = 1366
# Вызов функции с n = 1365
# Вызов функции с n = 1364
# Вызов функции с n = 1363
# Вызов функции с n = 1362
# Вызов функции с n = 1361
# Вызов функции с n = 1360
# Вызов функции с n = 1359
# Вызов функции с n = 1358
# Вызов функции с n = 1357
# Вызов функции с n = 1356
# Вызов функции с n = 1355
# Вызов функции с n = 1354
# Вызов функции с n = 1353
# Вызов функции с n = 1352
# Вызов функции с n = 1351
# Вызов функции с n = 1350
# Вызов функции с n = 1349
# Вызов функции с n = 1348
# Вызов функции с n = 1347
# Вызов функции с n = 1346
# Вызов функции с n = 1345
# Вызов функции с n = 1344
# Вызов функции с n = 1343
# Вызов функции с n = 1342
# Вызов функции с n = 1341
# Вызов функции с n = 1340
# Вызов функции с n = 1339
# Вызов функции с n = 1338
# Вызов функции с n = 1337
# Вызов функции с n = 1336
# Вызов функции с n = 1335
# Вызов функции с n = 1334
# Вызов функции с n = 1333
# Вызов функции с n = 1332
# Вызов функции с n = 1331
# Вызов функции с n = 1330
# Вызов функции с n = 1329
# Вызов функции с n = 1328
# Вызов функции с n = 1327
# Вызов функции с n = 1326
# Вызов функции с n = 1325
# Вызов функции с n = 1324
# Вызов функции с n = 1323
# Вызов функции с n = 1322
# Вызов функции с n = 1321
# Вызов функции с n = 1320
# Вызов функции с n = 1319
# Вызов функции с n = 1318
# Вызов функции с n = 1317
# Вызов функции с n = 1316
# Вызов функции с n = 1315
# Вызов функции с n = 1314
# Вызов функции с n = 1313
# Вызов функции с n = 1312
# Вызов функции с n = 1311
# Вызов функции с n = 1310
# Вызов функции с n = 1309
# Вызов функции с n = 1308
# Вызов функции с n = 1307
# Вызов функции с n = 1306
# Вызов функции с n = 1305
# Вызов функции с n = 1304
# Вызов функции с n = 1303
# Вызов функции с n = 1302
# Вызов функции с n = 1301
# Вызов функции с n = 1300
# Вызов функции с n = 1299
# Вызов функции с n = 1298
# Вызов функции с n = 1297
# Вызов функции с n = 1296
# Вызов функции с n = 1295
# Вызов функции с n = 1294
# Вызов функции с n = 1293
# Вызов функции с n = 1292
# Вызов функции с n = 1291
# Вызов функции с n = 1290
# Вызов функции с n = 1289
# Вызов функции с n = 1288
# Вызов функции с n = 1287
# Вызов функции с n = 1286
# Вызов функции с n = 1285
# Вызов функции с n = 1284
# Вызов функции с n = 1283
# Вызов функции с n = 1282
# Вызов функции с n = 1281
# Вызов функции с n = 1280
# Вызов функции с n = 1279
# Вызов функции с n = 1278
# Вызов функции с n = 1277
# Вызов функции с n = 1276
# Вызов функции с n = 1275
# Вызов функции с n = 1274
# Вызов функции с n = 1273
# Вызов функции с n = 1272
# Вызов функции с n = 1271
# Вызов функции с n = 1270
# Вызов функции с n = 1269
# Вызов функции с n = 1268
# Вызов функции с n = 1267
# Вызов функции с n = 1266
# Вызов функции с n = 1265
# Вызов функции с n = 1264
# Вызов функции с n = 1263
# Вызов функции с n = 1262
# Вызов функции с n = 1261
# Вызов функции с n = 1260
# Вызов функции с n = 1259
# Вызов функции с n = 1258
# Вызов функции с n = 1257
# Вызов функции с n = 1256
# Вызов функции с n = 1255
# Вызов функции с n = 1254
# Вызов функции с n = 1253
# Вызов функции с n = 1252
# Вызов функции с n = 1251
# Вызов функции с n = 1250
# Вызов функции с n = 1249
# Вызов функции с n = 1248
# Вызов функции с n = 1247
# Вызов функции с n = 1246
# Вызов функции с n = 1245
# Вызов функции с n = 1244
# Вызов функции с n = 1243
# Вызов функции с n = 1242
# Вызов функции с n = 1241
# Вызов функции с n = 1240
# Вызов функции с n = 1239
# Вызов функции с n = 1238
# Вызов функции с n = 1237
# Вызов функции с n = 1236
# Вызов функции с n = 1235
# Вызов функции с n = 1234
# Вызов функции с n = 1233
# Вызов функции с n = 1232
# Вызов функции с n = 1231
# Вызов функции с n = 1230
# Вызов функции с n = 1229
# Вызов функции с n = 1228
# Вызов функции с n = 1227
# Вызов функции с n = 1226
# Вызов функции с n = 1225
# Вызов функции с n = 1224
# Вызов функции с n = 1223
# Вызов функции с n = 1222
# Вызов функции с n = 1221
# Вызов функции с n = 1220
# Вызов функции с n = 1219
# Вызов функции с n = 1218
# Вызов функции с n = 1217
# Вызов функции с n = 1216
# Вызов функции с n = 1215
# Вызов функции с n = 1214
# Вызов функции с n = 1213
# Вызов функции с n = 1212
# Вызов функции с n = 1211
# Вызов функции с n = 1210
# Вызов функции с n = 1209
# Вызов функции с n = 1208
# Вызов функции с n = 1207
# Вызов функции с n = 1206
# Вызов функции с n = 1205
# Вызов функции с n = 1204
# Вызов функции с n = 1203
# Вызов функции с n = 1202
# Вызов функции с n = 1201
# Вызов функции с n = 1200
# Вызов функции с n = 1199
# Вызов функции с n = 1198
# Вызов функции с n = 1197
# Вызов функции с n = 1196
# Вызов функции с n = 1195
# Вызов функции с n = 1194
# Вызов функции с n = 1193
# Вызов функции с n = 1192
# Вызов функции с n = 1191
# Вызов функции с n = 1190
# Вызов функции с n = 1189
# Вызов функции с n = 1188
# Вызов функции с n = 1187
# Вызов функции с n = 1186
# Вызов функции с n = 1185
# Вызов функции с n = 1184
# Вызов функции с n = 1183
# Вызов функции с n = 1182
# Вызов функции с n = 1181
# Вызов функции с n = 1180
# Вызов функции с n = 1179
# Вызов функции с n = 1178
# Вызов функции с n = 1177
# Вызов функции с n = 1176
# Вызов функции с n = 1175
# Вызов функции с n = 1174
# Вызов функции с n = 1173
# Вызов функции с n = 1172
# Вызов функции с n = 1171
# Вызов функции с n = 1170
# Вызов функции с n = 1169
# Вызов функции с n = 1168
# Вызов функции с n = 1167
# Вызов функции с n = 1166
# Вызов функции с n = 1165
# Вызов функции с n = 1164
# Вызов функции с n = 1163
# Вызов функции с n = 1162
# Вызов функции с n = 1161
# Вызов функции с n = 1160
# Вызов функции с n = 1159
# Вызов функции с n = 1158
# Вызов функции с n = 1157
# Вызов функции с n = 1156
# Вызов функции с n = 1155
# Вызов функции с n = 1154
# Вызов функции с n = 1153
# Вызов функции с n = 1152
# Вызов функции с n = 1151
# Вызов функции с n = 1150
# Вызов функции с n = 1149
# Вызов функции с n = 1148
# Вызов функции с n = 1147
# Вызов функции с n = 1146
# Вызов функции с n = 1145
# Вызов функции с n = 1144
# Вызов функции с n = 1143
# Вызов функции с n = 1142
# Вызов функции с n = 1141
# Вызов функции с n = 1140
# Вызов функции с n = 1139
# Вызов функции с n = 1138
# Вызов функции с n = 1137
# Вызов функции с n = 1136
# Вызов функции с n = 1135
# Вызов функции с n = 1134
# Вызов функции с n = 1133
# Вызов функции с n = 1132
# Вызов функции с n = 1131
# Вызов функции с n = 1130
# Вызов функции с n = 1129
# Вызов функции с n = 1128
# Вызов функции с n = 1127
# Вызов функции с n = 1126
# Вызов функции с n = 1125
# Вызов функции с n = 1124
# Вызов функции с n = 1123
# Вызов функции с n = 1122
# Вызов функции с n = 1121
# Вызов функции с n = 1120
# Вызов функции с n = 1119
# Вызов функции с n = 1118
# Вызов функции с n = 1117
# Вызов функции с n = 1116
# Вызов функции с n = 1115
# Вызов функции с n = 1114
# Вызов функции с n = 1113
# Вызов функции с n = 1112
# Вызов функции с n = 1111
# Вызов функции с n = 1110
# Вызов функции с n = 1109
# Вызов функции с n = 1108
# Вызов функции с n = 1107
# Вызов функции с n = 1106
# Вызов функции с n = 1105
# Вызов функции с n = 1104
# Вызов функции с n = 1103
# Вызов функции с n = 1102
# Вызов функции с n = 1101
# Вызов функции с n = 1100
# Вызов функции с n = 1099
# Вызов функции с n = 1098
# Вызов функции с n = 1097
# Вызов функции с n = 1096
# Вызов функции с n = 1095
# Вызов функции с n = 1094
# Вызов функции с n = 1093
# Вызов функции с n = 1092
# Вызов функции с n = 1091
# Вызов функции с n = 1090
# Вызов функции с n = 1089
# Вызов функции с n = 1088
# Вызов функции с n = 1087
# Вызов функции с n = 1086
# Вызов функции с n = 1085
# Вызов функции с n = 1084
# Вызов функции с n = 1083
# Вызов функции с n = 1082
# Вызов функции с n = 1081
# Вызов функции с n = 1080
# Вызов функции с n = 1079
# Вызов функции с n = 1078
# Вызов функции с n = 1077
# Вызов функции с n = 1076
# Вызов функции с n = 1075
# Вызов функции с n = 1074
# Вызов функции с n = 1073
# Вызов функции с n = 1072
# Вызов функции с n = 1071
# Вызов функции с n = 1070
# Вызов функции с n = 1069
# Вызов функции с n = 1068
# Вызов функции с n = 1067
# Вызов функции с n = 1066
# Вызов функции с n = 1065
# Вызов функции с n = 1064
# Вызов функции с n = 1063
# Вызов функции с n = 1062
# Вызов функции с n = 1061
# Вызов функции с n = 1060
# Вызов функции с n = 1059
# Вызов функции с n = 1058
# Вызов функции с n = 1057
# Вызов функции с n = 1056
# Вызов функции с n = 1055
# Вызов функции с n = 1054
# Вызов функции с n = 1053
# Вызов функции с n = 1052
# Вызов функции с n = 1051
# Вызов функции с n = 1050
# Вызов функции с n = 1049
# Вызов функции с n = 1048
# Вызов функции с n = 1047
# Вызов функции с n = 1046
# Вызов функции с n = 1045
# Вызов функции с n = 1044
# Вызов функции с n = 1043
# Вызов функции с n = 1042
# Вызов функции с n = 1041
# Вызов функции с n = 1040
# Вызов функции с n = 1039
# Вызов функции с n = 1038
# Вызов функции с n = 1037
# Вызов функции с n = 1036
# Вызов функции с n = 1035
# Вызов функции с n = 1034
# Вызов функции с n = 1033
# Вызов функции с n = 1032
# Вызов функции с n = 1031
# Вызов функции с n = 1030
# Вызов функции с n = 1029
# Вызов функции с n = 1028
# Вызов функции с n = 1027
# Вызов функции с n = 1026
# Вызов функции с n = 1025
# Вызов функции с n = 1024
# Вызов функции с n = 1023
# Вызов функции с n = 1022
# Вызов функции с n = 1021
# Вызов функции с n = 1020
# Вызов функции с n = 1019
# Вызов функции с n = 1018
# Вызов функции с n = 1017
# Вызов функции с n = 1016
# Вызов функции с n = 1015
# Вызов функции с n = 1014
# Вызов функции с n = 1013
# Вызов функции с n = 1012
# Вызов функции с n = 1011
# Вызов функции с n = 1010
# Вызов функции с n = 1009
# Вызов функции с n = 1008
# Вызов функции с n = 1007
# Вызов функции с n = 1006
# Вызов функции с n = 1005
# Вызов функции с n = 1004
# Вызов функции с n = 1003
# Вызов функции с n = 1002
# Вызов функции с n = 1001
# Вызов функции с n = 1000
# Вызов функции с n = 999
# Вызов функции с n = 998
# Вызов функции с n = 997
# Вызов функции с n = 996
# Вызов функции с n = 995
# Вызов функции с n = 994
# Вызов функции с n = 993
# Вызов функции с n = 992
# Вызов функции с n = 991
# Вызов функции с n = 990
# Вызов функции с n = 989
# Вызов функции с n = 988
# Вызов функции с n = 987
# Вызов функции с n = 986
# Вызов функции с n = 985
# Вызов функции с n = 984
# Вызов функции с n = 983
# Вызов функции с n = 982
# Вызов функции с n = 981
# ...
# Вызов функции с n = 670
# Вызов функции с n = 669
# Вызов функции с n = 668
# Вызов функции с n = 667
# Вызов функции с n = 666
# Вызов функции с n = 665
# Вызов функции с n = 664
# Вызов функции с n = 663
# Вызов функции с n = 662
# Вызов функции с n = 661
# Вызов функции с n = 660
# Вызов функции с n = 659
# Вызов функции с n = 658
# Вызов функции с n = 657
# Вызов функции с n = 656
# Вызов функции с n = 655
# Вызов функции с n = 654
# Вызов функции с n = 653
# Вызов функции с n = 652
# Вызов функции с n = 651
# Вызов функции с n = 650
# Вызов функции с n = 649
# Вызов функции с n = 648
# Вызов функции с n = 647
# Вызов функции с n = 646
# Вызов функции с n = 645
# Вызов функции с n = 644
# Вызов функции с n = 643
# Вызов функции с n = 642
# Вызов функции с n = 641
# Вызов функции с n = 640
# Вызов функции с n = 639
# Вызов функции с n = 638
# Вызов функции с n = 637
# Вызов функции с n = 636
# Вызов функции с n = 635
# Вызов функции с n = 634
# Вызов функции с n = 633
# Вызов функции с n = 632
# Вызов функции с n = 631
# Вызов функции с n = 630
# Вызов функции с n = 629
# Вызов функции с n = 628
# Вызов функции с n = 627
# Вызов функции с n = 626
# Вызов функции с n = 625
# Вызов функции с n = 624
# Вызов функции с n = 623
# Вызов функции с n = 622
# Вызов функции с n = 621
# Вызов функции с n = 620
# Вызов функции с n = 619
# Вызов функции с n = 618
# Вызов функции с n = 617
# Вызов функции с n = 616
# Вызов функции с n = 615
# Вызов функции с n = 614
# Вызов функции с n = 613
# Вызов функции с n = 612
# Вызов функции с n = 611
# Вызов функции с n = 610
# Вызов функции с n = 609
# Вызов функции с n = 608
# Вызов функции с n = 607
# Вызов функции с n = 606
# Вызов функции с n = 605
# Вызов функции с n = 604
# Вызов функции с n = 603
# Вызов функции с n = 602
# Вызов функции с n = 601
# Вызов функции с n = 600
# Вызов функции с n = 599
# Вызов функции с n = 598
# Вызов функции с n = 597
# Вызов функции с n = 596
# Вызов функции с n = 595
# Вызов функции с n = 594
# Вызов функции с n = 593
# Вызов функции с n = 592
# Вызов функции с n = 591
# Вызов функции с n = 590
# Вызов функции с n = 589
# Вызов функции с n = 588
# Вызов функции с n = 587
# Вызов функции с n = 586
# Вызов функции с n = 585
# Вызов функции с n = 584
# Вызов функции с n = 583
# Вызов функции с n = 582
# Вызов функции с n = 581
# Вызов функции с n = 580
# Вызов функции с n = 579
# Вызов функции с n = 578
# Вызов функции с n = 577
# Вызов функции с n = 576
# Вызов функции с n = 575
# Вызов функции с n = 574
# Вызов функции с n = 573
# Вызов функции с n = 572
# Вызов функции с n = 571
# Вызов функции с n = 570
# Вызов функции с n = 569
# Вызов функции с n = 568
# Вызов функции с n = 567
# Вызов функции с n = 566
# Вызов функции с n = 565
# Вызов функции с n = 564
# Вызов функции с n = 563
# Вызов функции с n = 562
# Вызов функции с n = 561
# Вызов функции с n = 560
# Вызов функции с n = 559
# Вызов функции с n = 558
# Вызов функции с n = 557
# Вызов функции с n = 556
# Вызов функции с n = 555
# Вызов функции с n = 554
# Вызов функции с n = 553
# Вызов функции с n = 552
# Вызов функции с n = 551
# Вызов функции с n = 550
# Вызов функции с n = 549
# Вызов функции с n = 548
# Вызов функции с n = 547
# Вызов функции с n = 546
# Вызов функции с n = 545
# Вызов функции с n = 544
# Вызов функции с n = 543
# Вызов функции с n = 542
# Вызов функции с n = 541
# Вызов функции с n = 540
# Вызов функции с n = 539
# Вызов функции с n = 538
# Вызов функции с n = 537
# Вызов функции с n = 536
# Вызов функции с n = 535
# Вызов функции с n = 534
# Вызов функции с n = 533
# Вызов функции с n = 532
# Вызов функции с n = 531
# Вызов функции с n = 530
# Вызов функции с n = 529
# Вызов функции с n = 528
# Вызов функции с n = 527
# Вызов функции с n = 526
# Вызов функции с n = 525
# Вызов функции с n = 524
# Вызов функции с n = 523
# Вызов функции с n = 522
# Вызов функции с n = 521
# Вызов функции с n = 520
# Вызов функции с n = 519
# Вызов функции с n = 518
# Вызов функции с n = 517
# Вызов функции с n = 516
# Вызов функции с n = 515
# Вызов функции с n = 514
# Вызов функции с n = 513
# Вызов функции с n = 512
# Вызов функции с n = 511
# Вызов функции с n = 510
# Вызов функции с n = 509
# Вызов функции с n = 508
# Вызов функции с n = 507
# Вызов функции с n = 506
# Вызов функции с n = 505
# Вызов функции с n = 504
# Вызов функции с n = 503
# Вызов функции с n = 502
# Вызов функции с n = 501
# Вызов функции с n = 500
# Вызов функции с n = 499
# Вызов функции с n = 498
# Вызов функции с n = 497
# Вызов функции с n = 496
# Вызов функции с n = 495
# Вызов функции с n = 494
# Вызов функции с n = 493
# Вызов функции с n = 492
# Вызов функции с n = 491
# Вызов функции с n = 490
# Вызов функции с n = 489
# Вызов функции с n = 488
# Вызов функции с n = 487
# Вызов функции с n = 486
# Вызов функции с n = 485
# Вызов функции с n = 484
# Вызов функции с n = 483
# Вызов функции с n = 482
# Вызов функции с n = 481
# Вызов функции с n = 480
# Вызов функции с n = 479
# Вызов функции с n = 478
# Вызов функции с n = 477
# Вызов функции с n = 476
# Вызов функции с n = 475
# Вызов функции с n = 474
# Вызов функции с n = 473
# Вызов функции с n = 472
# Вызов функции с n = 471
# Вызов функции с n = 470
# Вызов функции с n = 469
# Вызов функции с n = 468
# Вызов функции с n = 467
# Вызов функции с n = 466
# Вызов функции с n = 465
# Вызов функции с n = 464
# Вызов функции с n = 463
# Вызов функции с n = 462
# Вызов функции с n = 461
# Вызов функции с n = 460
# Вызов функции с n = 459
# Вызов функции с n = 458
# Вызов функции с n = 457
# Вызов функции с n = 456
# Вызов функции с n = 455
# Вызов функции с n = 454
# Вызов функции с n = 453
# Вызов функции с n = 452
# Вызов функции с n = 451
# Вызов функции с n = 450
# Вызов функции с n = 449
# Вызов функции с n = 448
# Вызов функции с n = 447
# Вызов функции с n = 446
# Вызов функции с n = 445
# Вызов функции с n = 444
# Вызов функции с n = 443
# Вызов функции с n = 442
# Вызов функции с n = 441
# Вызов функции с n = 440
# Вызов функции с n = 439
# Вызов функции с n = 438
# Вызов функции с n = 437
# Вызов функции с n = 436
# Вызов функции с n = 435
# Вызов функции с n = 434
# Вызов функции с n = 433
# Вызов функции с n = 432
# Вызов функции с n = 431
# Вызов функции с n = 430
# Вызов функции с n = 429
# Вызов функции с n = 428
# Вызов функции с n = 427
# Вызов функции с n = 426
# Вызов функции с n = 425
# Вызов функции с n = 424
# Вызов функции с n = 423
# Вызов функции с n = 422
# Вызов функции с n = 421
# Вызов функции с n = 420
# Вызов функции с n = 419
# Вызов функции с n = 418
# Вызов функции с n = 417
# Вызов функции с n = 416
# Вызов функции с n = 415
# Вызов функции с n = 414
# Вызов функции с n = 413
# Вызов функции с n = 412
# Вызов функции с n = 411
# Вызов функции с n = 410
# Вызов функции с n = 409
# Вызов функции с n = 408
# Вызов функции с n = 407
# Вызов функции с n = 406
# Вызов функции с n = 405
# Вызов функции с n = 404
# Вызов функции с n = 403
# Вызов функции с n = 402
# Вызов функции с n = 401
# Вызов функции с n = 400
# Вызов функции с n = 399
# Вызов функции с n = 398
# Вызов функции с n = 397
# Вызов функции с n = 396
# Вызов функции с n = 395
# Вызов функции с n = 394
# Вызов функции с n = 393
# Вызов функции с n = 392
# Вызов функции с n = 391
# Вызов функции с n = 390
# Вызов функции с n = 389
# Вызов функции с n = 388
# Вызов функции с n = 387
# Вызов функции с n = 386
# Вызов функции с n = 385
# Вызов функции с n = 384
# Вызов функции с n = 383
# Вызов функции с n = 382
# Вызов функции с n = 381
# Вызов функции с n = 380
# Вызов функции с n = 379
# Вызов функции с n = 378
# Вызов функции с n = 377
# Вызов функции с n = 376
# Вызов функции с n = 375
# Вызов функции с n = 374
# Вызов функции с n = 373
# Вызов функции с n = 372
# Вызов функции с n = 371
# Вызов функции с n = 370
# Вызов функции с n = 369
# Вызов функции с n = 368
# Вызов функции с n = 367
# Вызов функции с n = 366
# Вызов функции с n = 365
# Вызов функции с n = 364
# Вызов функции с n = 363
# Вызов функции с n = 362
# Вызов функции с n = 361
# Вызов функции с n = 360
# Вызов функции с n = 359
# Вызов функции с n = 358
# Вызов функции с n = 357
# Вызов функции с n = 356
# Вызов функции с n = 355
# Вызов функции с n = 354
# Вызов функции с n = 353
# Вызов функции с n = 352
# Вызов функции с n = 351
# Вызов функции с n = 350
# Вызов функции с n = 349
# Вызов функции с n = 348
# Вызов функции с n = 347
# Вызов функции с n = 346
# Вызов функции с n = 345
# Вызов функции с n = 344
# Вызов функции с n = 343
# Вызов функции с n = 342
# Вызов функции с n = 341
# Вызов функции с n = 340
# Вызов функции с n = 339
# Вызов функции с n = 338
# Вызов функции с n = 337
# Вызов функции с n = 336
# Вызов функции с n = 335
# Вызов функции с n = 334
# Вызов функции с n = 333
# Вызов функции с n = 332
# Вызов функции с n = 331
# Вызов функции с n = 330
# Вызов функции с n = 329
# Вызов функции с n = 328
# Вызов функции с n = 327
# Вызов функции с n = 326
# Вызов функции с n = 325
# Вызов функции с n = 324
# Вызов функции с n = 323
# Вызов функции с n = 322
# Вызов функции с n = 321
# Вызов функции с n = 320
# Вызов функции с n = 319
# Вызов функции с n = 318
# Вызов функции с n = 317
# Вызов функции с n = 316
# Вызов функции с n = 315
# Вызов функции с n = 314
# Вызов функции с n = 313
# Вызов функции с n = 312
# Вызов функции с n = 311
# Вызов функции с n = 310
# Вызов функции с n = 309
# Вызов функции с n = 308
# Вызов функции с n = 307
# Вызов функции с n = 306
# Вызов функции с n = 305
# Вызов функции с n = 304
# Вызов функции с n = 303
# Вызов функции с n = 302
# Вызов функции с n = 301
# Вызов функции с n = 300
# Вызов функции с n = 299
# Вызов функции с n = 298
# Вызов функции с n = 297
# Вызов функции с n = 296
# Вызов функции с n = 295
# Вызов функции с n = 294
# Вызов функции с n = 293
# Вызов функции с n = 292
# Вызов функции с n = 291
# Вызов функции с n = 290
# Вызов функции с n = 289
# Вызов функции с n = 288
# Вызов функции с n = 287
# Вызов функции с n = 286
# Вызов функции с n = 285
# Вызов функции с n = 284
# Вызов функции с n = 283
# Вызов функции с n = 282
# Вызов функции с n = 281
# Вызов функции с n = 280
# Вызов функции с n = 279
# Вызов функции с n = 278
# Вызов функции с n = 277
# Вызов функции с n = 276
# Вызов функции с n = 275
# Вызов функции с n = 274
# Вызов функции с n = 273
# Вызов функции с n = 272
# Вызов функции с n = 271
# Вызов функции с n = 270
# Вызов функции с n = 269
# Вызов функции с n = 268
# Вызов функции с n = 267
# Вызов функции с n = 266
# Вызов функции с n = 265
# Вызов функции с n = 264
# Вызов функции с n = 263
# Вызов функции с n = 262
# Вызов функции с n = 261
# Вызов функции с n = 260
# Вызов функции с n = 259
# Вызов функции с n = 258
# Вызов функции с n = 257
# Вызов функции с n = 256
# Вызов функции с n = 255
# Вызов функции с n = 254
# Вызов функции с n = 253
# Вызов функции с n = 252
# Вызов функции с n = 251
# Вызов функции с n = 250
# Вызов функции с n = 249
# Вызов функции с n = 248
# Вызов функции с n = 247
# Вызов функции с n = 246
# Вызов функции с n = 245
# Вызов функции с n = 244
# Вызов функции с n = 243
# Вызов функции с n = 242
# Вызов функции с n = 241
# Вызов функции с n = 240
# Вызов функции с n = 239
# Вызов функции с n = 238
# Вызов функции с n = 237
# Вызов функции с n = 236
# Вызов функции с n = 235
# Вызов функции с n = 234
# Вызов функции с n = 233
# Вызов функции с n = 232
# Вызов функции с n = 231
# Вызов функции с n = 230
# Вызов функции с n = 229
# Вызов функции с n = 228
# Вызов функции с n = 227
# Вызов функции с n = 226
# Вызов функции с n = 225
# Вызов функции с n = 224
# Вызов функции с n = 223
# Вызов функции с n = 222
# Вызов функции с n = 221
# Вызов функции с n = 220
# Вызов функции с n = 219
# Вызов функции с n = 218
# Вызов функции с n = 217
# Вызов функции с n = 216
# Вызов функции с n = 215
# Вызов функции с n = 214
# Вызов функции с n = 213
# Вызов функции с n = 212
# Вызов функции с n = 211
# Вызов функции с n = 210
# Вызов функции с n = 209
# Вызов функции с n = 208
# Вызов функции с n = 207
# Вызов функции с n = 206
# Вызов функции с n = 205
# Вызов функции с n = 204
# Вызов функции с n = 203
# Вызов функции с n = 202
# Вызов функции с n = 201
# Вызов функции с n = 200
# Вызов функции с n = 199
# Вызов функции с n = 198
# Вызов функции с n = 197
# Вызов функции с n = 196
# Вызов функции с n = 195
# Вызов функции с n = 194
# Вызов функции с n = 193
# Вызов функции с n = 192
# Вызов функции с n = 191
# Вызов функции с n = 190
# Вызов функции с n = 189
# Вызов функции с n = 188
# Вызов функции с n = 187
# Вызов функции с n = 186
# Вызов функции с n = 185
# Вызов функции с n = 184
# Вызов функции с n = 183
# Вызов функции с n = 182
# Вызов функции с n = 181
# Вызов функции с n = 180
# Вызов функции с n = 179
# Вызов функции с n = 178
# Вызов функции с n = 177
# Вызов функции с n = 176
# Вызов функции с n = 175
# Вызов функции с n = 174
# Вызов функции с n = 173
# Вызов функции с n = 172
# Вызов функции с n = 171
# Вызов функции с n = 170
# Вызов функции с n = 169
# Вызов функции с n = 168
# Вызов функции с n = 167
# Вызов функции с n = 166
# Вызов функции с n = 165
# Вызов функции с n = 164
# Вызов функции с n = 163
# Вызов функции с n = 162
# Вызов функции с n = 161
# Вызов функции с n = 160
# Вызов функции с n = 159
# Вызов функции с n = 158
# Вызов функции с n = 157
# Вызов функции с n = 156
# Вызов функции с n = 155
# Вызов функции с n = 154
# Вызов функции с n = 153
# Вызов функции с n = 152
# Вызов функции с n = 151
# Вызов функции с n = 150
# Вызов функции с n = 149
# Вызов функции с n = 148
# Вызов функции с n = 147
# Вызов функции с n = 146
# Вызов функции с n = 145
# Вызов функции с n = 144
# Вызов функции с n = 143
# Вызов функции с n = 142
# Вызов функции с n = 141
# Вызов функции с n = 140
# Вызов функции с n = 139
# Вызов функции с n = 138
# Вызов функции с n = 137
# Вызов функции с n = 136
# Вызов функции с n = 135
# Вызов функции с n = 134
# Вызов функции с n = 133
# Вызов функции с n = 132
# Вызов функции с n = 131
# Вызов функции с n = 130
# Вызов функции с n = 129
# Вызов функции с n = 128
# Вызов функции с n = 127
# Вызов функции с n = 126
# Вызов функции с n = 125
# Вызов функции с n = 124
# Вызов функции с n = 123
# Вызов функции с n = 122
# Вызов функции с n = 121
# Вызов функции с n = 120
# Вызов функции с n = 119
# Вызов функции с n = 118
# Вызов функции с n = 117
# Вызов функции с n = 116
# Вызов функции с n = 115
# Вызов функции с n = 114
# Вызов функции с n = 113
# Вызов функции с n = 112
# Вызов функции с n = 111
# Вызов функции с n = 110
# Вызов функции с n = 109
# Вызов функции с n = 108
# Вызов функции с n = 107
# Вызов функции с n = 106
# Вызов функции с n = 105
# Вызов функции с n = 104
# Вызов функции с n = 103
# Вызов функции с n = 102
# Вызов функции с n = 101
# Вызов функции с n = 100
# Вызов функции с n = 99
# Вызов функции с n = 98
# Вызов функции с n = 97
# Вызов функции с n = 96
# Вызов функции с n = 95
# Вызов функции с n = 94
# Вызов функции с n = 93
# Вызов функции с n = 92
# Вызов функции с n = 91
# Вызов функции с n = 90
# Вызов функции с n = 89
# Вызов функции с n = 88
# Вызов функции с n = 87
# Вызов функции с n = 86
# Вызов функции с n = 85
# Вызов функции с n = 84
# Вызов функции с n = 83
# Вызов функции с n = 82
# Вызов функции с n = 81
# Вызов функции с n = 80
# Вызов функции с n = 79
# Вызов функции с n = 78
# Вызов функции с n = 77
# Вызов функции с n = 76
# Вызов функции с n = 75
# Вызов функции с n = 74
# Вызов функции с n = 73
# Вызов функции с n = 72
# Вызов функции с n = 71
# Вызов функции с n = 70
# Вызов функции с n = 69
# Вызов функции с n = 68
# Вызов функции с n = 67
# Вызов функции с n = 66
# Вызов функции с n = 65
# Вызов функции с n = 64
# Вызов функции с n = 63
# Вызов функции с n = 62
# Вызов функции с n = 61
# Вызов функции с n = 60
# Вызов функции с n = 59
# Вызов функции с n = 58
# Вызов функции с n = 57
# Вызов функции с n = 56
# Вызов функции с n = 55
# Вызов функции с n = 54
# Вызов функции с n = 53
# Вызов функции с n = 52
# Вызов функции с n = 51
# Вызов функции с n = 50
# Вызов функции с n = 49
# Вызов функции с n = 48
# Вызов функции с n = 47
# Вызов функции с n = 46
# Вызов функции с n = 45
# Вызов функции с n = 44
# Вызов функции с n = 43
# Вызов функции с n = 42
# Вызов функции с n = 41
# Вызов функции с n = 40
# Вызов функции с n = 39
# Вызов функции с n = 38
# Вызов функции с n = 37
# Вызов функции с n = 36
# Вызов функции с n = 35
# Вызов функции с n = 34
# Вызов функции с n = 33
# Вызов функции с n = 32
# Вызов функции с n = 31
# Вызов функции с n = 30
# Вызов функции с n = 29
# Вызов функции с n = 28
# Вызов функции с n = 27
# Вызов функции с n = 26
# Вызов функции с n = 25
# Вызов функции с n = 24
# Вызов функции с n = 23
# Вызов функции с n = 22
# Вызов функции с n = 21
# Вызов функции с n = 20
# Вызов функции с n = 19
# Вызов функции с n = 18
# Вызов функции с n = 17
# Вызов функции с n = 16
# Вызов функции с n = 15
# Вызов функции с n = 14
# Вызов функции с n = 13
# Вызов функции с n = 12
# Вызов функции с n = 11
# Вызов функции с n = 10
# Вызов функции с n = 9
# Вызов функции с n = 8
# Вызов функции с n = 7
# Вызов функции с n = 6
# Вызов функции с n = 5
# Вызов функции с n = 4
# Вызов функции с n = 3
# Вызов функции с n = 2
# Вызов функции с n = 1
# Вызов функции с n = 0
# ...

# %% [markdown]
# Не забывайте про выход из рекурсии! Иначе можно получить бесконечную рекурсию.

# %% [markdown]
# ## Работа с файлами/папками

# %% [markdown]
# ### Чтение/запись в файл

# %%
file_object = open('1.txt', mode='w')

# %% [markdown]
# 'r' - чтение
#
# 'w' - запись (существующий файл будет стерт и перезаписан)
#
# 'a' - дозапись (append)
#
# 'r+' - и чтение, и запись

# %%
file_object
# Out:
# <_io.TextIOWrapper name='1.txt' mode='w' encoding='UTF-8'>

# %%
file_object.writelines(['1 line\n', '2 line\n'])

# %%
file_object.write('3 line\n')
# Out:
# 7

# %%
file_object.close()

# %%
# !cat 1.txt
# Out:
# 1 line
# 2 line
# 3 line

# %%
file_object = open('1.txt', 'r')

print (file_object.read())

file_object.close()
# Out:
# 1 line
# 2 line
# 3 line

# %%
file_object = open('1.txt', 'r')

line = file_object.readline()

while line:
    print (line)
    print()

    line= file_object.readline()
    
file_object.close()
# Out:
# 1 line
#
#
# 2 line
#
#
# 3 line

# %%
file_object = open('1.txt', 'r')

for i in file_object.readline():
    print (i)
    
file_object.close()
# Out:
# 1
#
# l
# i
# n
# e

# %%
file_object = open('1.txt', 'r')

for i in file_object.readlines():
    print (i)
    
file_object.close()
# Out:
# 1 line
#
# 2 line
#
# 3 line

# %%
file_object = open('1.txt', 'r')

print (type(file_object.readlines()))

file_object.close()
# Out:
# <class 'list'>

# %% [markdown]
# #### Контекстный оператор with

# %%
with open('1.txt', 'r') as context_file_object:
    lines = context_file_object.readlines()

# %%
context_file_object.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-d98aef74ba3f> in <module>
# ----> 1 context_file_object.read()
#
# ValueError: I/O operation on closed file.

# %%
lines
# Out:
# ['1 line\n', '2 line\n', '3 line\n']

# %%
with open('1.txt', 'r') as context_file_object:
    for line in context_file_object:
        print (line)
# Out:
# 1 line
#
# 2 line
#
# 3 line

# %% [markdown]
# ### Работа с директориями

# %%
import os

# %%
dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_TRAPPED',
#  'DirEntry',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'MutableMapping',
#  'NGROUPS_MAX',
#  'O_ACCMODE',
#  'O_APPEND',
#  'O_ASYNC',
#  'O_CLOEXEC',
#  'O_CREAT',
#  'O_DIRECTORY',
#  'O_DSYNC',
#  'O_EXCL',
#  'O_EXLOCK',
#  'O_NDELAY',
#  'O_NOCTTY',
#  'O_NOFOLLOW',
#  'O_NONBLOCK',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SHLOCK',
#  'O_SYNC',
#  'O_TRUNC',
#  'O_WRONLY',
#  'PRIO_PGRP',
#  'PRIO_PROCESS',
#  'PRIO_USER',
#  'P_ALL',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_PGID',
#  'P_PID',
#  'P_WAIT',
#  'PathLike',
#  'RTLD_GLOBAL',
#  'RTLD_LAZY',
#  'RTLD_LOCAL',
#  'RTLD_NODELETE',
#  'RTLD_NOLOAD',
#  'RTLD_NOW',
#  'R_OK',
#  'SCHED_FIFO',
#  'SCHED_OTHER',
#  'SCHED_RR',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'ST_NOSUID',
#  'ST_RDONLY',
#  'TMP_MAX',
#  'WCONTINUED',
#  'WCOREDUMP',
#  'WEXITED',
#  'WEXITSTATUS',
#  'WIFCONTINUED',
#  'WIFEXITED',
#  'WIFSIGNALED',
#  'WIFSTOPPED',
#  'WNOHANG',
#  'WNOWAIT',
#  'WSTOPPED',
#  'WSTOPSIG',
#  'WTERMSIG',
#  'WUNTRACED',
#  'W_OK',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_fwalk',
#  '_get_exports_list',
#  '_putenv',
#  '_spawnvef',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chflags',
#  'chmod',
#  'chown',
#  'chroot',
#  'close',
#  'closerange',
#  'confstr',
#  'confstr_names',
#  'cpu_count',
#  'ctermid',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'environb',
#  'error',
#  'execl',
#  'execle',
#  'execlp',
#  'execlpe',
#  'execv',
#  'execve',
#  'execvp',
#  'execvpe',
#  'extsep',
#  'fchdir',
#  'fchmod',
#  'fchown',
#  'fdopen',
#  'fork',
#  'forkpty',
#  'fpathconf',
#  'fsdecode',
#  'fsencode',
#  'fspath',
#  'fstat',
#  'fstatvfs',
#  'fsync',
#  'ftruncate',
#  'fwalk',
#  'get_blocking',
#  'get_exec_path',
#  'get_inheritable',
#  'get_terminal_size',
#  'getcwd',
#  'getcwdb',
#  'getegid',
#  'getenv',
#  'getenvb',
#  'geteuid',
#  'getgid',
#  'getgrouplist',
#  'getgroups',
#  'getloadavg',
#  'getlogin',
#  'getpgid',
#  'getpgrp',
#  'getpid',
#  'getppid',
#  'getpriority',
#  'getsid',
#  'getuid',
#  'initgroups',
#  'isatty',
#  'kill',
#  'killpg',
#  'lchflags',
#  'lchmod',
#  'lchown',
#  'linesep',
#  'link',
#  'listdir',
#  'lockf',
#  'lseek',
#  'lstat',
#  'major',
#  'makedev',
#  'makedirs',
#  'minor',
#  'mkdir',
#  'mkfifo',
#  'mknod',
#  'name',
#  'nice',
#  'open',
#  'openpty',
#  'pardir',
#  'path',
#  'pathconf',
#  'pathconf_names',
#  'pathsep',
#  'pipe',
#  'popen',
#  'pread',
#  'putenv',
#  'pwrite',
#  'read',
#  'readlink',
#  'readv',
#  'register_at_fork',
#  'remove',
#  'removedirs',
#  'rename',
#  'renames',
#  'replace',
#  'rmdir',
#  'scandir',
#  'sched_get_priority_max',
#  'sched_get_priority_min',
#  'sched_yield',
#  'sendfile',
#  'sep',
#  'set_blocking',
#  'set_inheritable',
#  'setegid',
#  'seteuid',
#  'setgid',
#  'setgroups',
#  'setpgid',
#  'setpgrp',
#  'setpriority',
#  'setregid',
#  'setreuid',
#  'setsid',
#  'setuid',
#  'spawnl',
#  'spawnle',
#  'spawnlp',
#  'spawnlpe',
#  'spawnv',
#  'spawnve',
#  'spawnvp',
#  'spawnvpe',
#  'st',
#  'stat',
#  'stat_result',
#  'statvfs',
#  'statvfs_result',
#  'strerror',
#  'supports_bytes_environ',
#  'supports_dir_fd',
#  'supports_effective_ids',
#  'supports_fd',
#  'supports_follow_symlinks',
#  'symlink',
#  'sync',
#  'sys',
#  'sysconf',
#  'sysconf_names',
#  'system',
#  'tcgetpgrp',
#  'tcsetpgrp',
#  'terminal_size',
#  'times',
#  'times_result',
#  'truncate',
#  'ttyname',
#  'umask',
#  'uname',
#  'uname_result',
#  'unlink',
#  'unsetenv',
#  'urandom',
#  'utime',
#  'wait',
#  'wait3',
#  'wait4',
#  'waitpid',
#  'walk',
#  'write',
#  'writev']

# %%
os.listdir()
# Out:
# ['museums.csv',
#  'Seminar 2.ipynb',
#  'states_info.csv',
#  'tutorial',
#  '.DS_Store',
#  'Seminar 4.ipynb',
#  'Seminar 6.ipynb',
#  'Seminar 1.ipynb',
#  'Lecture 8.ipynb',
#  'Seminar 3.ipynb',
#  'Seminar 7.ipynb',
#  'google-play-store-apps',
#  'Seminar 5.ipynb',
#  'Seminar 9.ipynb',
#  'Lecture 2.ipynb',
#  'Homework 1.ipynb',
#  'Lecture 6.ipynb',
#  'Lecture 4.ipynb',
#  '1.txt',
#  '.ipynb_checkpoints',
#  'Lecture 3.ipynb',
#  'Seminar 8.ipynb',
#  'Lecture 1.ipynb',
#  'Lecture 5.ipynb',
#  'data.txt',
#  'Lecture 7.ipynb']

# %%
os.listdir('/Users/arbochkarev')[:10]
# Out:
# ['.eclipse',
#  'Music',
#  '.anyconnect',
#  '.DS_Store',
#  '.CFUserTextEncoding',
#  '.zshrc',
#  'Creative Cloud Files',
#  'Pictures',
#  '.zsh_history',
#  '.ipython']

# %%
# выведем только папки

basepath = '/Users/arbochkarev'

for path in os.listdir(basepath):
    full_path = os.path.join(basepath, path)
    
    if os.path.isdir(full_path):
        print (path)
        
#     if os.path.isfile(full_path):
#         print (path)
# Out:
# .eclipse
# Music
# Creative Cloud Files
# Pictures
# .ipython
# Desktop
# Library
# .matplotlib
# Zotero
# Public
# .cisco
# .ssh
# Movies
# Applications
# opt
# .Trash
# .jupyter
# Documents
# .vscode
# Downloads
# .conda

# %%
os.mkdir('lect_4_dir')
os.mkdir('lect_4_dir/some_dir')

# %%
# !ls lect_4_dir
# Out:
# some_dir

# %%
os.rmdir('lect_4_dir/some_dir', )

# %%
os.rmdir('lect_4_dir')
